# %%
import pandas as pd
import numpy as np
import hashlib
import time

print("Starting the data processing...")

# Function to load a CSV file given its file path
def load_file(file_path):
    return pd.read_csv(file_path)

# File paths and file names
base_path = "/home/uottawa.o.univ/hpate033/GAN Project/CIC-DDoS2019/"
files = [
    "DrDoS_LDAP.csv", "DrDoS_MSSQL.csv", "DrDoS_NetBIOS.csv",
    "DrDoS_NTP.csv", "DrDoS_SNMP.csv", "DrDoS_SSDP.csv",
    "DrDoS_UDP.csv", "DrDoS_DNS.csv"
]

print(f"Total files to process: {len(files)}")

# List to store balanced samples from each file
balanced_dfs = []

for i, file in enumerate(files, 1):
    print(f"\nProcessing file {i} of {len(files)}: {file}")
    start_time = time.time()
    
    file_path = base_path + file
    try:
        df = load_file(file_path)
        print(f"  {file} loaded successfully!")
    except FileNotFoundError:
        print(f"  Error: {file_path} not found!")
        continue
    
    print("  Cleaning and preprocessing data...")
    # Replace infinite values
    df = df.replace(['Infinity', np.inf], 0)
    
    # Convert numerical columns safely
    df[' Flow Packets/s'] = pd.to_numeric(df[' Flow Packets/s'], errors='coerce').fillna(0)
    df['Flow Bytes/s'] = pd.to_numeric(df['Flow Bytes/s'], errors='coerce').fillna(0)
    
    # Convert labels to numeric
    df[' Label'] = df[' Label'].replace({
        'BENIGN': 0, 
        'DrDoS_DNS': 1, 'DrDoS_LDAP': 1, 'DrDoS_MSSQL': 1,
        'DrDoS_NTP': 1, 'DrDoS_NetBIOS': 1, 'DrDoS_SNMP': 1, 'DrDoS_SSDP': 1,
        'DrDoS_UDP': 1
    }).astype(int)
    
    # Drop unnecessary columns
    df.drop(columns=[' Timestamp', ' Source IP', ' Destination IP', 'Flow ID', 'SimillarHTTP', 'Unnamed: 0'], inplace=True)
    
    # Remove extra spaces in column names
    df.columns = df.columns.str.strip()
    
    print("  Sampling data...")
    # Sample 100000 benign and 100000 DrDoS (attack) samples
    benign_df = df[df['Label'] == 0]
    attack_df = df[df['Label'] == 1]
    
    if len(benign_df) < 100000:
        print(f"  Warning: {file} has only {len(benign_df)} benign samples.")
        benign_sample = benign_df
    else:
        benign_sample = benign_df.sample(n=100000, random_state=42)
    
    if len(attack_df) < 100000:
        print(f"  Warning: {file} has only {len(attack_df)} DrDoS samples.")
        attack_sample = attack_df
    else:
        attack_sample = attack_df.sample(n=100000, random_state=42)
    
    balanced_sample = pd.concat([benign_sample, attack_sample], ignore_index=True)
    balanced_dfs.append(balanced_sample)
    print(f"  {file}: Selected {len(benign_sample)} benign and {len(attack_sample)} DrDoS samples.")
    
    end_time = time.time()
    print(f"  Time taken to process {file}: {end_time - start_time:.2f} seconds")

print("\nCombining all balanced samples...")
# Combine balanced samples from all files into one benchmarking dataframe
benchmark_df = pd.concat(balanced_dfs, ignore_index=True)
print("Benchmark dataframe created successfully!")

print("\nFinal benchmark dataframe info:")
benchmark_df.info()

print("\nProcessing complete!")

# A helper function that converts a string into a numeric hash (if needed later)
def string2numeric_hash(text):
    return int(hashlib.md5(text.encode()).hexdigest()[:8], 16)
# Out:
# Starting the data processing...
# Total files to process: 8
#
# Processing file 1 of 8: DrDoS_LDAP.csv
# /tmp/ipykernel_837763/290030618.py:31: DtypeWarning: Columns (85) have mixed types.Specify dtype option on import or set low_memory=False.
#   df = load_file(file_path)
#   DrDoS_LDAP.csv loaded successfully!
#   Cleaning and preprocessing data...
#   Sampling data...
#   Warning: DrDoS_LDAP.csv has only 1612 benign samples.
#   DrDoS_LDAP.csv: Selected 1612 benign and 100000 DrDoS samples.
#   Time taken to process DrDoS_LDAP.csv: 14.50 seconds
#
# Processing file 2 of 8: DrDoS_MSSQL.csv
#   DrDoS_MSSQL.csv loaded successfully!
#   Cleaning and preprocessing data...
#   Sampling data...
#   Warning: DrDoS_MSSQL.csv has only 2006 benign samples.
#   DrDoS_MSSQL.csv: Selected 2006 benign and 100000 DrDoS samples.
#   Time taken to process DrDoS_MSSQL.csv: 30.26 seconds
#
# Processing file 3 of 8: DrDoS_NetBIOS.csv
#   DrDoS_NetBIOS.csv loaded successfully!
#   Cleaning and preprocessing data...
#   Sampling data...
#   Warning: DrDoS_NetBIOS.csv has only 1707 benign samples.
#   DrDoS_NetBIOS.csv: Selected 1707 benign and 100000 DrDoS samples.
#   Time taken to process DrDoS_NetBIOS.csv: 26.32 seconds
#
# Processing file 4 of 8: DrDoS_NTP.csv
#   DrDoS_NTP.csv loaded successfully!
#   Cleaning and preprocessing data...
#   Sampling data...
#   Warning: DrDoS_NTP.csv has only 14365 benign samples.
#   DrDoS_NTP.csv: Selected 14365 benign and 100000 DrDoS samples.
#   Time taken to process DrDoS_NTP.csv: 8.85 seconds
#
# Processing file 5 of 8: DrDoS_SNMP.csv
#   DrDoS_SNMP.csv loaded successfully!
#   Cleaning and preprocessing data...
#   Sampling data...
#   Warning: DrDoS_SNMP.csv has only 1507 benign samples.
#   DrDoS_SNMP.csv: Selected 1507 benign and 100000 DrDoS samples.
#   Time taken to process DrDoS_SNMP.csv: 32.92 seconds
#
# Processing file 6 of 8: DrDoS_SSDP.csv
#   DrDoS_SSDP.csv loaded successfully!
#   Cleaning and preprocessing data...
#   Sampling data...
#   Warning: DrDoS_SSDP.csv has only 763 benign samples.
#   DrDoS_SSDP.csv: Selected 763 benign and 100000 DrDoS samples.
#   Time taken to process DrDoS_SSDP.csv: 18.38 seconds
#
# Processing file 7 of 8: DrDoS_UDP.csv
#   DrDoS_UDP.csv loaded successfully!
#   Cleaning and preprocessing data...
#   Sampling data...
#   Warning: DrDoS_UDP.csv has only 2157 benign samples.
#   DrDoS_UDP.csv: Selected 2157 benign and 100000 DrDoS samples.
#   Time taken to process DrDoS_UDP.csv: 21.75 seconds
#
# Processing file 8 of 8: DrDoS_DNS.csv
#   DrDoS_DNS.csv loaded successfully!
#   Cleaning and preprocessing data...
#   Sampling data...
#   Warning: DrDoS_DNS.csv has only 3402 benign samples.
#   DrDoS_DNS.csv: Selected 3402 benign and 100000 DrDoS samples.
#   Time taken to process DrDoS_DNS.csv: 33.60 seconds
#
# Combining all balanced samples...
# Benchmark dataframe created successfully!
#
# Final benchmark dataframe info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 827519 entries, 0 to 827518
# Data columns (total 82 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Source Port                  827519 non-null  int64
#  1   Destination Port             827519 non-null  int64
#  2   Protocol                     827519 non-null  int64
#  3   Flow Duration                827519 non-null  int64
#  4   Total Fwd Packets            827519 non-null  int64
#  5   Total Backward Packets       827519 non-null  int64
#  6   Total Length of Fwd Packets  827519 non-null  float64
#  7   Total Length of Bwd Packets  827519 non-null  float64
#  8   Fwd Packet Length Max        827519 non-null  float64
#  9   Fwd Packet Length Min        827519 non-null  float64
#  10  Fwd Packet Length Mean       827519 non-null  float64
#  11  Fwd Packet Length Std        827519 non-null  float64
#  12  Bwd Packet Length Max        827519 non-null  float64
#  13  Bwd Packet Length Min        827519 non-null  float64
#  14  Bwd Packet Length Mean       827519 non-null  float64
#  15  Bwd Packet Length Std        827519 non-null  float64
#  16  Flow Bytes/s                 827519 non-null  float64
#  17  Flow Packets/s               827519 non-null  float64
#  18  Flow IAT Mean                827519 non-null  float64
#  19  Flow IAT Std                 827519 non-null  float64
#  20  Flow IAT Max                 827519 non-null  float64
#  21  Flow IAT Min                 827519 non-null  float64
#  22  Fwd IAT Total                827519 non-null  float64
#  23  Fwd IAT Mean                 827519 non-null  float64
#  24  Fwd IAT Std                  827519 non-null  float64
#  25  Fwd IAT Max                  827519 non-null  float64
#  26  Fwd IAT Min                  827519 non-null  float64
#  27  Bwd IAT Total                827519 non-null  float64
#  28  Bwd IAT Mean                 827519 non-null  float64
#  29  Bwd IAT Std                  827519 non-null  float64
#  30  Bwd IAT Max                  827519 non-null  float64
#  31  Bwd IAT Min                  827519 non-null  float64
#  32  Fwd PSH Flags                827519 non-null  int64
#  33  Bwd PSH Flags                827519 non-null  int64
#  34  Fwd URG Flags                827519 non-null  int64
#  35  Bwd URG Flags                827519 non-null  int64
#  36  Fwd Header Length            827519 non-null  int64
#  37  Bwd Header Length            827519 non-null  int64
#  38  Fwd Packets/s                827519 non-null  float64
#  39  Bwd Packets/s                827519 non-null  float64
#  40  Min Packet Length            827519 non-null  float64
#  41  Max Packet Length            827519 non-null  float64
#  42  Packet Length Mean           827519 non-null  float64
#  43  Packet Length Std            827519 non-null  float64
#  44  Packet Length Variance       827519 non-null  float64
#  45  FIN Flag Count               827519 non-null  int64
#  46  SYN Flag Count               827519 non-null  int64
#  47  RST Flag Count               827519 non-null  int64
#  48  PSH Flag Count               827519 non-null  int64
#  49  ACK Flag Count               827519 non-null  int64
#  50  URG Flag Count               827519 non-null  int64
#  51  CWE Flag Count               827519 non-null  int64
#  52  ECE Flag Count               827519 non-null  int64
#  53  Down/Up Ratio                827519 non-null  float64
#  54  Average Packet Size          827519 non-null  float64
#  55  Avg Fwd Segment Size         827519 non-null  float64
#  56  Avg Bwd Segment Size         827519 non-null  float64
#  57  Fwd Header Length.1          827519 non-null  int64
#  58  Fwd Avg Bytes/Bulk           827519 non-null  int64
#  59  Fwd Avg Packets/Bulk         827519 non-null  int64
#  60  Fwd Avg Bulk Rate            827519 non-null  int64
#  61  Bwd Avg Bytes/Bulk           827519 non-null  int64
#  62  Bwd Avg Packets/Bulk         827519 non-null  int64
#  63  Bwd Avg Bulk Rate            827519 non-null  int64
#  64  Subflow Fwd Packets          827519 non-null  int64
#  65  Subflow Fwd Bytes            827519 non-null  int64
#  66  Subflow Bwd Packets          827519 non-null  int64
#  67  Subflow Bwd Bytes            827519 non-null  int64
#  68  Init_Win_bytes_forward       827519 non-null  int64
#  69  Init_Win_bytes_backward      827519 non-null  int64
#  70  act_data_pkt_fwd             827519 non-null  int64
#  71  min_seg_size_forward         827519 non-null  int64
#  72  Active Mean                  827519 non-null  float64
#  73  Active Std                   827519 non-null  float64
#  74  Active Max                   827519 non-null  float64
#  75  Active Min                   827519 non-null  float64
#  76  Idle Mean                    827519 non-null  float64
#  77  Idle Std                     827519 non-null  float64
#  78  Idle Max                     827519 non-null  float64
#  79  Idle Min                     827519 non-null  float64
#  80  Inbound                      827519 non-null  int64
#  81  Label                        827519 non-null  int64
# dtypes: float64(45), int64(37)
# memory usage: 517.7 MB
#
# Processing complete!

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif, f_classif
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import matplotlib.pyplot as plt
import time

print("Starting DDoS detection feature selection experiment...")

# Load dataset 
print("Loading dataset...")
X = benchmark_df.drop('Label', axis=1)
y = benchmark_df['Label']
print(f"Dataset loaded: {X.shape[0]} samples with {X.shape[1]} features")

# Split data
print("Splitting data into training and test sets...")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
print(f"Training set: {X_train.shape[0]} samples, Test set: {X_test.shape[0]} samples")

# Standardize features
print("Standardizing features...")
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
print("Feature standardization complete")

print("Defining top features based on sensitivity ranking and synergistic pairs...")
# Define top features (Sensitivity Ranking + Synergistic Pairs)
top_features_sensitivity = [
    'Inbound', 'Protocol', 'URG Flag Count', 'Down/Up Ratio', 'ACK Flag Count',
    'Fwd PSH Flags', 'RST Flag Count', 'Bwd Packet Length Min', 'CWE Flag Count',
    'SYN Flag Count', 'Bwd IAT Min', 'Subflow Bwd Bytes', 'Bwd Packet Length Max',
    'Init_Win_bytes_backward', 'Bwd Header Length', 'act_data_pkt_fwd',
    'Total Length of Bwd Packets', 'Active Std', 'Active Min', 'Init_Win_bytes_forward',
    'Total Backward Packets', 'Subflow Bwd Packets', 'Fwd Packet Length Min',
    'Fwd Packet Length Max', 'Avg Bwd Segment Size', 'Bwd Packet Length Std',
    'Active Mean', 'Fwd IAT Min', 'Max Packet Length', 'Active Max',
    'Subflow Fwd Bytes', 'Subflow Fwd Packets', 'Bwd Packet Length Mean',
    'Average Packet Size', 'Idle Std', 'Total Fwd Packets', 'Avg Fwd Segment Size',
    'Fwd Packet Length Mean', 'Min Packet Length', 'Total Length of Fwd Packets',
    'Flow IAT Min', 'Fwd Packet Length Std', 'Packet Length Mean', 'Packet Length Variance',
    'Bwd IAT Mean', 'Bwd IAT Max', 'min_seg_size_forward', 'Bwd IAT Total', 'Idle Min',
    'Idle Mean', 'Bwd Packets/s', 'Packet Length Std', 'Bwd IAT Std', 'Idle Max',
    'Fwd Header Length.1', 'Fwd Header Length', 'Source Port', 'Destination Port',
    'Flow IAT Max', 'Fwd IAT Max', 'Flow Duration', 'Fwd IAT Total', 'Fwd IAT Mean',
    'Flow Bytes/s', 'Flow IAT Mean', 'Fwd Packets/s', 'Flow Packets/s', 'Flow IAT Std',
    'Fwd IAT Std', 'Bwd Avg Bulk Rate', 'Bwd Avg Packets/Bulk'
]

print(f"Sensitivity-ranked features: {len(top_features_sensitivity)} features")
print("First 5 features:", top_features_sensitivity[:5])
print("Last 5 features:", top_features_sensitivity[-5:])

# Combine individual and pairwise features into a new feature set
print("Creating GAN feature set...")
GAN_features = list(top_features_sensitivity)
print(f"GAN feature set created with {len(GAN_features)} features")

# Initialize models
print("Initializing machine learning models...")
models = {
    'Logistic Regression': LogisticRegression(max_iter=1000),
    'Random Forest': RandomForestClassifier()
}
print(f"Initialized {len(models)} models: {', '.join(models.keys())}")

# Initialize feature selection techniques
def get_best_features_selector(method, k_features):
    if method == 'Chi-Square':
        return SelectKBest(score_func=chi2, k=k_features)
    elif method == 'ANOVA':
        return SelectKBest(score_func=f_classif, k=k_features)
    elif method == 'Mutual Information':
        return SelectKBest(score_func=mutual_info_classif, k=k_features)

# Initialize results structure
results = {
    metric: {
        method: {
            model_name: [] for model_name in models.keys()
        } for method in ['Chi-Square', 'ANOVA', 'Mutual Information', 'GAN_FS']
    } for metric in ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'AUC-ROC']
}

# Initialize training times structure
training_times = {
    method: {
        model_name: [] for model_name in models.keys()
    } for method in ['Chi-Square', 'ANOVA', 'Mutual Information', 'GAN_FS']
}

# Apply feature selection once with max features
max_features = 71
fs_outputs = {}
for fs_method in ['Chi-Square', 'ANOVA', 'Mutual Information']:
    print(f"Applying {fs_method} feature selection with {max_features} features...")
    fs = get_best_features_selector(fs_method, max_features)
    fs.fit(X_train, y_train)
    fs_outputs[fs_method] = fs

print("Feature selection outputs stored for Chi-Square, ANOVA, and Mutual Information.")

# Iterate over number of features to select
feature_counts = range(10, 71, 10)
print(f"Starting evaluation with feature counts: {list(feature_counts)}")

for k in feature_counts:
    print(f"\nProcessing with {k} features...")
    
    # For traditional feature selection methods
    for fs_method in ['Chi-Square', 'ANOVA', 'Mutual Information']:
        print(f"  Using top {k} features from {fs_method}...")
        
        # Get the indices of the top k features
        top_k_indices = fs_outputs[fs_method].scores_.argsort()[-k:][::-1]
        
        # Select the top k features
        X_train_fs = X_train[:, top_k_indices]
        X_test_fs = X_test[:, top_k_indices]
        
        for model_name, model in models.items():
            print(f"    Training {model_name}...")
            
            # Measure training time
            start_time = time.time()
            model.fit(X_train_fs, y_train)
            end_time = time.time()
            training_time = end_time - start_time
            
            # Store the training time
            training_times[fs_method][model_name].append(training_time)
            print(f"    {model_name} training completed in {training_time:.4f} seconds")
            
            y_pred = model.predict(X_test_fs)
            y_prob = model.predict_proba(X_test_fs)[:, 1]

            # Store results directly for this model
            results['Accuracy'][fs_method][model_name].append(accuracy_score(y_test, y_pred))
            results['Precision'][fs_method][model_name].append(precision_score(y_test, y_pred))
            results['Recall'][fs_method][model_name].append(recall_score(y_test, y_pred))
            results['F1 Score'][fs_method][model_name].append(f1_score(y_test, y_pred))
            results['AUC-ROC'][fs_method][model_name].append(roc_auc_score(y_test, y_prob))
            print(f"    {model_name} evaluation complete")
    
    # For GAN feature set
    print(f"  Applying GAN feature selection...")
    X_train_GAN = X_train[:, [X.columns.get_loc(f) for f in GAN_features[:k]]]
    X_test_GAN = X_test[:, [X.columns.get_loc(f) for f in GAN_features[:k]]]

    for model_name, model in models.items():
        print(f"    Training {model_name} with GAN features...")
        
        # Measure training time
        start_time = time.time()
        model.fit(X_train_GAN, y_train)
        end_time = time.time()
        training_time = end_time - start_time
        
        # Store the training time
        training_times['GAN_FS'][model_name].append(training_time)
        print(f"    {model_name} training completed in {training_time:.4f} seconds")
        
        y_pred = model.predict(X_test_GAN)
        y_prob = model.predict_proba(X_test_GAN)[:, 1]

        # Store results directly for this model
        results['Accuracy']['GAN_FS'][model_name].append(accuracy_score(y_test, y_pred))
        results['Precision']['GAN_FS'][model_name].append(precision_score(y_test, y_pred))
        results['Recall']['GAN_FS'][model_name].append(recall_score(y_test, y_pred))
        results['F1 Score']['GAN_FS'][model_name].append(f1_score(y_test, y_pred))
        results['AUC-ROC']['GAN_FS'][model_name].append(roc_auc_score(y_test, y_prob))
        print(f"    {model_name} evaluation complete")
    
    print(f"Completed evaluation with {k} features")

print("All feature selection evaluations complete. Generating plots...")

# Plotting the performance results
print("Creating overall performance comparison plot...")
plt.figure(figsize=(20, 15))
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'AUC-ROC']

for idx, metric in enumerate(metrics, 1):
    plt.subplot(len(metrics), 1, idx)
    
    for method in ['Chi-Square', 'ANOVA', 'Mutual Information', 'GAN_FS']:
        for model_name in models.keys():
            plt.plot(
                feature_counts, 
                results[metric][method][model_name], 
                label=f"{method} - {model_name}"
            )
    
    plt.title(metric)
    plt.xlabel('Number of Features')
    plt.ylabel(metric)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.xticks(feature_counts)
    plt.grid(True)

plt.tight_layout()
print("Displaying overall performance comparison plot...")
plt.show()

# One figure per model for performance metrics
print("Creating individual model performance plots...")
for model_name in models.keys():
    print(f"  Generating plot for {model_name}...")
    plt.figure(figsize=(15, 10))
    
    for idx, metric in enumerate(metrics, 1):
        plt.subplot(2, 3, idx)
        
        for method in ['Chi-Square', 'ANOVA', 'Mutual Information', 'GAN_FS']:
            plt.plot(
                feature_counts, 
                results[metric][method][model_name], 
                label=method
            )
        
        plt.title(f"{model_name} - {metric}")
        plt.xlabel('Number of Features')
        plt.ylabel(metric)
        plt.legend()
        plt.xticks(feature_counts)
    
    plt.tight_layout()
    plt.suptitle(f"Performance Metrics for {model_name}", fontsize=16)
    plt.subplots_adjust(top=0.93)
    print(f"  Displaying plot for {model_name}...")
    plt.show()

# Add plot for training times - overall comparison
print("Creating training time comparison plot...")
plt.figure(figsize=(15, 8))

for method in ['Chi-Square', 'ANOVA', 'Mutual Information', 'GAN_FS']:
    for model_name in models.keys():
        plt.plot(
            feature_counts, 
            training_times[method][model_name], 
            label=f"{method} - {model_name}",
            marker='o'
        )

plt.title("Training Time Comparison")
plt.xlabel('Number of Features')
plt.ylabel('Training Time (seconds)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(feature_counts)
plt.grid(True)
plt.tight_layout()
print("Displaying training time comparison plot...")
plt.show()

# Plot training time for each model separately
print("Creating model-specific training time plots...")
for model_name in models.keys():
    plt.figure(figsize=(10, 6))
    
    for method in ['Chi-Square', 'ANOVA', 'Mutual Information', 'GAN_FS']:
        plt.plot(
            feature_counts, 
            training_times[method][model_name], 
            label=method,
            marker='o'
        )
    
    plt.title(f"Training Time for {model_name}")
    plt.xlabel('Number of Features')
    plt.ylabel('Training Time (seconds)')
    plt.legend()
    plt.xticks(feature_counts)
    plt.grid(True)
    plt.tight_layout()
    print(f"  Displaying training time plot for {model_name}...")
    plt.show()

print("Experiment completed successfully!")
print(results)
# Out:
# Starting DDoS detection feature selection experiment...
# Loading dataset...
# Dataset loaded: 827519 samples with 81 features
# Splitting data into training and test sets...
# Training set: 579263 samples, Test set: 248256 samples
# Standardizing features...
# Feature standardization complete
# Defining top features based on sensitivity ranking and synergistic pairs...
# Sensitivity-ranked features: 71 features
# First 5 features: ['Inbound', 'Protocol', 'URG Flag Count', 'Down/Up Ratio', 'ACK Flag Count']
# Last 5 features: ['Flow Packets/s', 'Flow IAT Std', 'Fwd IAT Std', 'Bwd Avg Bulk Rate', 'Bwd Avg Packets/Bulk']
# Creating GAN feature set...
# GAN feature set created with 71 features
# Initializing machine learning models...
# Initialized 2 models: Logistic Regression, Random Forest
# Applying Chi-Square feature selection with 71 features...
# Applying ANOVA feature selection with 71 features...
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:114: UserWarning: Features [33 34 35 45 48 52 58 59 60 61 62 63] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# Applying Mutual Information feature selection with 71 features...
# Feature selection outputs stored for Chi-Square, ANOVA, and Mutual Information.
# Starting evaluation with feature counts: [10, 20, 30, 40, 50, 60, 70]
#
# Processing with 10 features...
#   Using top 10 features from Chi-Square...
#     Training Logistic Regression...
#     Logistic Regression training completed in 0.4087 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 5.2494 seconds
#     Random Forest evaluation complete
#   Using top 10 features from ANOVA...
#     Training Logistic Regression...
#     Logistic Regression training completed in 0.4026 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 5.2728 seconds
#     Random Forest evaluation complete
#   Using top 10 features from Mutual Information...
#     Training Logistic Regression...
#     Logistic Regression training completed in 1.9787 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 27.2567 seconds
#     Random Forest evaluation complete
#   Applying GAN feature selection...
#     Training Logistic Regression with GAN features...
#     Logistic Regression training completed in 2.1482 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest with GAN features...
#     Random Forest training completed in 6.8467 seconds
#     Random Forest evaluation complete
# Completed evaluation with 10 features
#
# Processing with 20 features...
#   Using top 20 features from Chi-Square...
#     Training Logistic Regression...
#     Logistic Regression training completed in 2.7207 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 17.1883 seconds
#     Random Forest evaluation complete
#   Using top 20 features from ANOVA...
#     Training Logistic Regression...
#     Logistic Regression training completed in 2.2633 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 7.3060 seconds
#     Random Forest evaluation complete
#   Using top 20 features from Mutual Information...
#     Training Logistic Regression...
#     Logistic Regression training completed in 4.1941 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 36.0209 seconds
#     Random Forest evaluation complete
#   Applying GAN feature selection...
#     Training Logistic Regression with GAN features...
#     Logistic Regression training completed in 3.9526 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest with GAN features...
#     Random Forest training completed in 10.4065 seconds
#     Random Forest evaluation complete
# Completed evaluation with 20 features
#
# Processing with 30 features...
#   Using top 30 features from Chi-Square...
#     Training Logistic Regression...
#     Logistic Regression training completed in 4.2181 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 19.8753 seconds
#     Random Forest evaluation complete
#   Using top 30 features from ANOVA...
#     Training Logistic Regression...
#     Logistic Regression training completed in 4.5987 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 16.2410 seconds
#     Random Forest evaluation complete
#   Using top 30 features from Mutual Information...
#     Training Logistic Regression...
#     Logistic Regression training completed in 5.0406 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 36.7847 seconds
#     Random Forest evaluation complete
#   Applying GAN feature selection...
#     Training Logistic Regression with GAN features...
#     Logistic Regression training completed in 5.4831 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest with GAN features...
#     Random Forest training completed in 16.7382 seconds
#     Random Forest evaluation complete
# Completed evaluation with 30 features
#
# Processing with 40 features...
#   Using top 40 features from Chi-Square...
#     Training Logistic Regression...
#     Logistic Regression training completed in 4.0557 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 24.6266 seconds
#     Random Forest evaluation complete
#   Using top 40 features from ANOVA...
#     Training Logistic Regression...
#     Logistic Regression training completed in 4.5484 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 24.0869 seconds
#     Random Forest evaluation complete
#   Using top 40 features from Mutual Information...
#     Training Logistic Regression...
#     Logistic Regression training completed in 4.6740 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 35.1515 seconds
#     Random Forest evaluation complete
#   Applying GAN feature selection...
#     Training Logistic Regression with GAN features...
#     Logistic Regression training completed in 5.2113 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest with GAN features...
#     Random Forest training completed in 24.2318 seconds
#     Random Forest evaluation complete
# Completed evaluation with 40 features
#
# Processing with 50 features...
#   Using top 50 features from Chi-Square...
#     Training Logistic Regression...
#     Logistic Regression training completed in 5.3468 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 32.6012 seconds
#     Random Forest evaluation complete
#   Using top 50 features from ANOVA...
#     Training Logistic Regression...
#     Logistic Regression training completed in 4.4212 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 28.1912 seconds
#     Random Forest evaluation complete
#   Using top 50 features from Mutual Information...
#     Training Logistic Regression...
#     Logistic Regression training completed in 10.2993 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 37.4946 seconds
#     Random Forest evaluation complete
#   Applying GAN feature selection...
#     Training Logistic Regression with GAN features...
#     Logistic Regression training completed in 6.7054 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest with GAN features...
#     Random Forest training completed in 26.3141 seconds
#     Random Forest evaluation complete
# Completed evaluation with 50 features
#
# Processing with 60 features...
#   Using top 60 features from Chi-Square...
#     Training Logistic Regression...
#     Logistic Regression training completed in 5.8825 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 34.9549 seconds
#     Random Forest evaluation complete
#   Using top 60 features from ANOVA...
#     Training Logistic Regression...
#     Logistic Regression training completed in 5.4764 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 34.6885 seconds
#     Random Forest evaluation complete
#   Using top 60 features from Mutual Information...
#     Training Logistic Regression...
#     Logistic Regression training completed in 12.2662 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 36.0516 seconds
#     Random Forest evaluation complete
#   Applying GAN feature selection...
#     Training Logistic Regression with GAN features...
#     Logistic Regression training completed in 11.3970 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest with GAN features...
#     Random Forest training completed in 29.8766 seconds
#     Random Forest evaluation complete
# Completed evaluation with 60 features
#
# Processing with 70 features...
#   Using top 70 features from Chi-Square...
#     Training Logistic Regression...
#     Logistic Regression training completed in 6.8559 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 34.3170 seconds
#     Random Forest evaluation complete
#   Using top 70 features from ANOVA...
#     Training Logistic Regression...
#     Logistic Regression training completed in 7.9567 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 34.1541 seconds
#     Random Forest evaluation complete
#   Using top 70 features from Mutual Information...
#     Training Logistic Regression...
#     Logistic Regression training completed in 13.3142 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 36.5917 seconds
#     Random Forest evaluation complete
#   Applying GAN feature selection...
#     Training Logistic Regression with GAN features...
#     Logistic Regression training completed in 13.4517 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest with GAN features...
#     Random Forest training completed in 38.0095 seconds
#     Random Forest evaluation complete
# Completed evaluation with 70 features
# All feature selection evaluations complete. Generating plots...
# Creating overall performance comparison plot...
# Displaying overall performance comparison plot...
# Creating individual model performance plots...
#   Generating plot for Logistic Regression...
#   Displaying plot for Logistic Regression...
#   Generating plot for Random Forest...
#   Displaying plot for Random Forest...
# Creating training time comparison plot...
# Displaying training time comparison plot...
# Creating model-specific training time plots...
#   Displaying training time plot for Logistic Regression...
#   Displaying training time plot for Random Forest...
# Experiment completed successfully!
# {'Accuracy': {'Chi-Square': {'Logistic Regression': [0.967231406290281, 0.986626707914411, 0.9990050592936324, 0.999323279195669, 0.9992910543954627, 0.9993071667955659, 0.9993273072956947], 'Random Forest': [0.967231406290281, 0.9988197666924465, 0.9995125998968807, 0.9999395784996133, 0.999963747099768, 0.9999516627996906, 0.9999516627996906]}, 'ANOVA': {'Logistic Regression': [0.967231406290281, 0.998920469193091, 0.9989446377932457, 0.9992668857953081, 0.9993192510956432, 0.9993152229956175, 0.999323279195669], 'Random Forest': [0.967231406290281, 0.9996858081979891, 0.9998267916988914, 0.9998831850992523, 0.999891241299304, 0.9999597189997422, 0.9999476346996649]}, 'Mutual Information': {'Logistic Regression': [0.9991540989945862, 0.9991943799948441, 0.9991863237947924, 0.9992104923949472, 0.9992991105955144, 0.9993031386955401, 0.999323279195669], 'Random Forest': [0.9994803750966744, 0.9999436065996391, 0.9998952693993297, 0.9999556908997165, 0.9999556908997165, 0.9999516627996906, 0.9999516627996906]}, 'GAN_FS': {'Logistic Regression': [0.998920469193091, 0.9991178460943542, 0.9993635601959268, 0.9993152229956175, 0.9993273072956947, 0.9993273072956947, 0.999323279195669], 'Random Forest': [0.9993353634957464, 0.9998187354988399, 0.999927494199536, 0.9999315222995617, 0.9999234660995102, 0.9999556908997165, 0.9999516627996906]}}, 'Precision': {'Chi-Square': {'Logistic Regression': [0.967231406290281, 0.9870424226967393, 0.9997291711804803, 0.9997459127356034, 0.9997917057218438, 0.9997750534248117, 0.999795877559862], 'Random Forest': [0.967231406290281, 0.9989971287087512, 0.9999416734714284, 1.0, 1.0, 1.0, 1.0]}, 'ANOVA': {'Logistic Regression': [0.967231406290281, 0.99972914748128, 0.9997291542529032, 0.9997708801119771, 0.9998166972171305, 0.9997833829747349, 0.9997917126634535], 'Random Forest': [0.967231406290281, 0.9997293617517373, 0.9998917253154541, 0.9999875051020833, 0.9999875052061641, 1.0, 1.0]}, 'Mutual Information': {'Logistic Regression': [0.9998416580898132, 0.9998708241833797, 0.9998666572215532, 0.9998375020312246, 0.9997958716074069, 0.9998250233302226, 0.9997958767095325], 'Random Forest': [0.9999833333333333, 0.999987505882647, 0.9999708465738477, 1.0, 1.0, 0.9999958352595258, 1.0]}, 'GAN_FS': {'Logistic Regression': [0.99972914748128, 0.9998374864572047, 0.9998208699057276, 0.9998042033785332, 0.9998125343686991, 0.999795877559862, 0.9997958767095325], 'Random Forest': [0.9997417527490836, 0.9998709075614854, 0.9999875056745061, 0.999987505726542, 0.9999875056224699, 1.0, 1.0]}}, 'Recall': {'Chi-Square': {'Logistic Regression': [1.0, 0.9992920236047659, 0.9992420488003965, 0.9995543913277056, 0.9994752645541206, 0.9995085810903669, 0.9995085810903669], 'Random Forest': [1.0, 0.999783442514399, 0.9995543913277056, 0.9999375314945381, 0.9999625188967229, 0.9999500251956306, 0.9999500251956306]}, 'ANOVA': {'Logistic Regression': [1.0, 0.9991545928927499, 0.9991795802949346, 0.9994710999870898, 0.9994794291211514, 0.9995085810903669, 0.9995085810903669], 'Random Forest': [1.0, 0.9999458606285998, 0.9999292023604766, 0.9998917212571995, 0.9999000503912611, 0.9999583543296922, 0.9999458606285998]}, 'Mutual Information': {'Logistic Regression': [0.9992836944707043, 0.9992961881717968, 0.9992920236047659, 0.9993461629761662, 0.9994794291211514, 0.9994544417189667, 0.9995044165233361], 'Random Forest': [0.9994794291211514, 0.9999541897626614, 0.999920873226415, 0.9999541897626614, 0.9999541897626614, 0.9999541897626614, 0.9999500251956306]}, 'GAN_FS': {'Logistic Regression': [0.9991545928927499, 0.999250377934458, 0.9995210747914594, 0.999487758255213, 0.9994919228222438, 0.9995085810903669, 0.9995044165233361], 'Random Forest': [0.9995710495958288, 0.9999416960615689, 0.9999375314945381, 0.9999416960615689, 0.9999333669275073, 0.9999541897626614, 0.9999500251956306]}}, 'F1 Score': {'Chi-Square': {'Logistic Regression': [0.9833427864129557, 0.9931294518875382, 0.9994855506378548, 0.9996501428583329, 0.99 ...

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif, f_classif
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import matplotlib.pyplot as plt
import time

print("Starting DDoS detection feature selection experiment...")

# Load dataset 
print("Loading dataset...")
X = benchmark_df.drop('Label', axis=1)
y = benchmark_df['Label']
print(f"Dataset loaded: {X.shape[0]} samples with {X.shape[1]} features")

# Split data
print("Splitting data into training and test sets...")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
print(f"Training set: {X_train.shape[0]} samples, Test set: {X_test.shape[0]} samples")

# Standardize features
print("Standardizing features...")
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
print("Feature standardization complete")

print("Defining top features based on sensitivity ranking and synergistic pairs...")
# Define top features (Sensitivity Ranking + Synergistic Pairs)
top_features_sensitivity = [
    'Inbound', 'Protocol', 'URG Flag Count', 'Down/Up Ratio', 'ACK Flag Count',
    'Fwd PSH Flags', 'RST Flag Count', 'Bwd Packet Length Min', 'CWE Flag Count',
    'SYN Flag Count', 'Bwd IAT Min', 'Subflow Bwd Bytes', 'Bwd Packet Length Max',
    'Init_Win_bytes_backward', 'Bwd Header Length', 'act_data_pkt_fwd',
    'Total Length of Bwd Packets', 'Active Std', 'Active Min', 'Init_Win_bytes_forward',
    'Total Backward Packets', 'Subflow Bwd Packets', 'Fwd Packet Length Min',
    'Fwd Packet Length Max', 'Avg Bwd Segment Size', 'Bwd Packet Length Std',
    'Active Mean', 'Fwd IAT Min', 'Max Packet Length', 'Active Max',
    'Subflow Fwd Bytes', 'Subflow Fwd Packets', 'Bwd Packet Length Mean',
    'Average Packet Size', 'Idle Std', 'Total Fwd Packets', 'Avg Fwd Segment Size',
    'Fwd Packet Length Mean', 'Min Packet Length', 'Total Length of Fwd Packets',
    'Flow IAT Min', 'Fwd Packet Length Std', 'Packet Length Mean', 'Packet Length Variance',
    'Bwd IAT Mean', 'Bwd IAT Max', 'min_seg_size_forward', 'Bwd IAT Total', 'Idle Min',
    'Idle Mean', 'Bwd Packets/s', 'Packet Length Std', 'Bwd IAT Std', 'Idle Max',
    'Fwd Header Length.1', 'Fwd Header Length', 'Source Port', 'Destination Port',
    'Flow IAT Max', 'Fwd IAT Max', 'Flow Duration', 'Fwd IAT Total', 'Fwd IAT Mean',
    'Flow Bytes/s', 'Flow IAT Mean', 'Fwd Packets/s', 'Flow Packets/s', 'Flow IAT Std',
    'Fwd IAT Std', 'Bwd Avg Bulk Rate', 'Bwd Avg Packets/Bulk'
]

print(f"Sensitivity-ranked features: {len(top_features_sensitivity)} features")
print("First 5 features:", top_features_sensitivity[:5])
print("Last 5 features:", top_features_sensitivity[-5:])

synergistic_pairs = [
    ('Subflow Bwd Bytes', 'Active Min'),
    ('Bwd Packet Length Min', 'Subflow Bwd Bytes'),
    ('Active Std', 'Active Min'),
    ('Bwd IAT Min', 'Subflow Bwd Bytes'),
    ('Bwd Header Length', 'act_data_pkt_fwd'),
    ('act_data_pkt_fwd', 'Total Length of Bwd Packets'),
    ('Down/Up Ratio', 'Subflow Bwd Bytes'),
    ('Init_Win_bytes_backward', 'act_data_pkt_fwd'),
    ('Subflow Bwd Bytes', 'Init_Win_bytes_forward'),
    ('Bwd IAT Min', 'Active Std'),
    ('Down/Up Ratio', 'Active Min'),
    ('RST Flag Count', 'Subflow Bwd Bytes'),
    ('RST Flag Count', 'Active Min'),
    ('Fwd PSH Flags', 'Subflow Bwd Bytes'),
    ('SYN Flag Count', 'Subflow Bwd Bytes'),
    ('Bwd Packet Length Min', 'Active Min'),
    ('Bwd IAT Min', 'Active Min'),
    ('Bwd Packet Length Max', 'act_data_pkt_fwd'),
    ('CWE Flag Count', 'act_data_pkt_fwd'),
    ('Bwd Packet Length Max', 'Active Min')
]

# Combine individual and pairwise features into a new feature set
print("Creating GAN feature set...")
GAN_features = list(set(top_features_sensitivity + [f for pair in synergistic_pairs for f in pair]))

# Ensure we have exactly 71 features
if len(GAN_features) > 71:
    GAN_features = GAN_features[:71]
elif len(GAN_features) < 71:
    remaining_features = [f for f in X.columns if f not in GAN_features]
    GAN_features.extend(remaining_features[:71 - len(GAN_features)])
print(f"GAN feature set created with {len(GAN_features)} features")

# Initialize models
print("Initializing machine learning models...")
models = {
    'Logistic Regression': LogisticRegression(max_iter=1000),
    'Random Forest': RandomForestClassifier()
}
print(f"Initialized {len(models)} models: {', '.join(models.keys())}")

# Initialize feature selection techniques
def get_best_features_selector(method, k_features):
    if method == 'Chi-Square':
        return SelectKBest(score_func=chi2, k=k_features)
    elif method == 'ANOVA':
        return SelectKBest(score_func=f_classif, k=k_features)
    elif method == 'Mutual Information':
        return SelectKBest(score_func=mutual_info_classif, k=k_features)

# Initialize results structure
results = {
    metric: {
        method: {
            model_name: [] for model_name in models.keys()
        } for method in ['Chi-Square', 'ANOVA', 'Mutual Information', 'GAN_FS']
    } for metric in ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'AUC-ROC']
}

# Initialize training times structure
training_times = {
    method: {
        model_name: [] for model_name in models.keys()
    } for method in ['Chi-Square', 'ANOVA', 'Mutual Information', 'GAN_FS']
}

# Apply feature selection once with max features
max_features = 71
fs_outputs = {}
for fs_method in ['Chi-Square', 'ANOVA', 'Mutual Information']:
    print(f"Applying {fs_method} feature selection with {max_features} features...")
    fs = get_best_features_selector(fs_method, max_features)
    fs.fit(X_train, y_train)
    fs_outputs[fs_method] = fs

print("Feature selection outputs stored for Chi-Square, ANOVA, and Mutual Information.")

# Iterate over number of features to select
feature_counts = range(10, 71, 10)
print(f"Starting evaluation with feature counts: {list(feature_counts)}")

for k in feature_counts:
    print(f"\nProcessing with {k} features...")
    
    # For traditional feature selection methods
    for fs_method in ['Chi-Square', 'ANOVA', 'Mutual Information']:
        print(f"  Using top {k} features from {fs_method}...")
        
        # Get the indices of the top k features
        top_k_indices = fs_outputs[fs_method].scores_.argsort()[-k:][::-1]
        
        # Select the top k features
        X_train_fs = X_train[:, top_k_indices]
        X_test_fs = X_test[:, top_k_indices]
        
        for model_name, model in models.items():
            print(f"    Training {model_name}...")
            
            # Measure training time
            start_time = time.time()
            model.fit(X_train_fs, y_train)
            end_time = time.time()
            training_time = end_time - start_time
            
            # Store the training time
            training_times[fs_method][model_name].append(training_time)
            print(f"    {model_name} training completed in {training_time:.4f} seconds")
            
            y_pred = model.predict(X_test_fs)
            y_prob = model.predict_proba(X_test_fs)[:, 1]

            # Store results directly for this model
            results['Accuracy'][fs_method][model_name].append(accuracy_score(y_test, y_pred))
            results['Precision'][fs_method][model_name].append(precision_score(y_test, y_pred))
            results['Recall'][fs_method][model_name].append(recall_score(y_test, y_pred))
            results['F1 Score'][fs_method][model_name].append(f1_score(y_test, y_pred))
            results['AUC-ROC'][fs_method][model_name].append(roc_auc_score(y_test, y_prob))
            print(f"    {model_name} evaluation complete")
    
    # For GAN feature set
    print(f"  Applying GAN feature selection...")
    X_train_GAN = X_train[:, [X.columns.get_loc(f) for f in GAN_features[:k]]]
    X_test_GAN = X_test[:, [X.columns.get_loc(f) for f in GAN_features[:k]]]

    for model_name, model in models.items():
        print(f"    Training {model_name} with GAN features...")
        
        # Measure training time
        start_time = time.time()
        model.fit(X_train_GAN, y_train)
        end_time = time.time()
        training_time = end_time - start_time
        
        # Store the training time
        training_times['GAN_FS'][model_name].append(training_time)
        print(f"    {model_name} training completed in {training_time:.4f} seconds")
        
        y_pred = model.predict(X_test_GAN)
        y_prob = model.predict_proba(X_test_GAN)[:, 1]

        # Store results directly for this model
        results['Accuracy']['GAN_FS'][model_name].append(accuracy_score(y_test, y_pred))
        results['Precision']['GAN_FS'][model_name].append(precision_score(y_test, y_pred))
        results['Recall']['GAN_FS'][model_name].append(recall_score(y_test, y_pred))
        results['F1 Score']['GAN_FS'][model_name].append(f1_score(y_test, y_pred))
        results['AUC-ROC']['GAN_FS'][model_name].append(roc_auc_score(y_test, y_prob))
        print(f"    {model_name} evaluation complete")
    
    print(f"Completed evaluation with {k} features")

print("All feature selection evaluations complete. Generating plots...")

# Plotting the performance results
print("Creating overall performance comparison plot...")
plt.figure(figsize=(20, 15))
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'AUC-ROC']

for idx, metric in enumerate(metrics, 1):
    plt.subplot(len(metrics), 1, idx)
    
    for method in ['Chi-Square', 'ANOVA', 'Mutual Information', 'GAN_FS']:
        for model_name in models.keys():
            plt.plot(
                feature_counts, 
                results[metric][method][model_name], 
                label=f"{method} - {model_name}"
            )
    
    plt.title(metric)
    plt.xlabel('Number of Features')
    plt.ylabel(metric)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.xticks(feature_counts)
    plt.grid(True)

plt.tight_layout()
print("Displaying overall performance comparison plot...")
plt.show()

# One figure per model for performance metrics
print("Creating individual model performance plots...")
for model_name in models.keys():
    print(f"  Generating plot for {model_name}...")
    plt.figure(figsize=(15, 10))
    
    for idx, metric in enumerate(metrics, 1):
        plt.subplot(2, 3, idx)
        
        for method in ['Chi-Square', 'ANOVA', 'Mutual Information', 'GAN_FS']:
            plt.plot(
                feature_counts, 
                results[metric][method][model_name], 
                label=method
            )
        
        plt.title(f"{model_name} - {metric}")
        plt.xlabel('Number of Features')
        plt.ylabel(metric)
        plt.legend()
        plt.xticks(feature_counts)
    
    plt.tight_layout()
    plt.suptitle(f"Performance Metrics for {model_name}", fontsize=16)
    plt.subplots_adjust(top=0.93)
    print(f"  Displaying plot for {model_name}...")
    plt.show()

# Add plot for training times - overall comparison
print("Creating training time comparison plot...")
plt.figure(figsize=(15, 8))

for method in ['Chi-Square', 'ANOVA', 'Mutual Information', 'GAN_FS']:
    for model_name in models.keys():
        plt.plot(
            feature_counts, 
            training_times[method][model_name], 
            label=f"{method} - {model_name}",
            marker='o'
        )

plt.title("Training Time Comparison")
plt.xlabel('Number of Features')
plt.ylabel('Training Time (seconds)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(feature_counts)
plt.grid(True)
plt.tight_layout()
print("Displaying training time comparison plot...")
plt.show()

# Plot training time for each model separately
print("Creating model-specific training time plots...")
for model_name in models.keys():
    plt.figure(figsize=(10, 6))
    
    for method in ['Chi-Square', 'ANOVA', 'Mutual Information', 'GAN_FS']:
        plt.plot(
            feature_counts, 
            training_times[method][model_name], 
            label=method,
            marker='o'
        )
    
    plt.title(f"Training Time for {model_name}")
    plt.xlabel('Number of Features')
    plt.ylabel('Training Time (seconds)')
    plt.legend()
    plt.xticks(feature_counts)
    plt.grid(True)
    plt.tight_layout()
    print(f"  Displaying training time plot for {model_name}...")
    plt.show()

print("Experiment completed successfully!")
print(results)
# Out:
# Starting DDoS detection feature selection experiment...
# Loading dataset...
# Dataset loaded: 827519 samples with 81 features
# Splitting data into training and test sets...
# Training set: 579263 samples, Test set: 248256 samples
# Standardizing features...
# Feature standardization complete
# Defining top features based on sensitivity ranking and synergistic pairs...
# Sensitivity-ranked features: 71 features
# First 5 features: ['Inbound', 'Protocol', 'URG Flag Count', 'Down/Up Ratio', 'ACK Flag Count']
# Last 5 features: ['Flow Packets/s', 'Flow IAT Std', 'Fwd IAT Std', 'Bwd Avg Bulk Rate', 'Bwd Avg Packets/Bulk']
# Creating combined feature set...
# Combined feature set created with 71 features
# Initializing machine learning models...
# Initialized 2 models: Logistic Regression, Random Forest
# Applying Chi-Square feature selection with 71 features...
# Applying ANOVA feature selection with 71 features...
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:114: UserWarning: Features [33 34 35 45 48 52 58 59 60 61 62 63] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# Applying Mutual Information feature selection with 71 features...
# Feature selection outputs stored for Chi-Square, ANOVA, and Mutual Information.
# Starting evaluation with feature counts: [10, 20, 30, 40, 50, 60, 70]
#
# Processing with 10 features...
#   Using top 10 features from Chi-Square...
#     Training Logistic Regression...
#     Logistic Regression training completed in 0.6777 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 7.7249 seconds
#     Random Forest evaluation complete
#   Using top 10 features from ANOVA...
#     Training Logistic Regression...
#     Logistic Regression training completed in 0.6472 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 7.8903 seconds
#     Random Forest evaluation complete
#   Using top 10 features from Mutual Information...
#     Training Logistic Regression...
#     Logistic Regression training completed in 3.2755 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 45.5858 seconds
#     Random Forest evaluation complete
#   Applying Combined feature selection...
#     Training Logistic Regression with combined features...
#     Logistic Regression training completed in 4.6810 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest with combined features...
#     Random Forest training completed in 27.6855 seconds
#     Random Forest evaluation complete
# Completed evaluation with 10 features
#
# Processing with 20 features...
#   Using top 20 features from Chi-Square...
#     Training Logistic Regression...
#     Logistic Regression training completed in 4.6719 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 27.1628 seconds
#     Random Forest evaluation complete
#   Using top 20 features from ANOVA...
#     Training Logistic Regression...
#     Logistic Regression training completed in 3.6860 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 10.7207 seconds
#     Random Forest evaluation complete
#   Using top 20 features from Mutual Information...
#     Training Logistic Regression...
#     Logistic Regression training completed in 7.1880 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 53.5511 seconds
#     Random Forest evaluation complete
#   Applying Combined feature selection...
#     Training Logistic Regression with combined features...
#     Logistic Regression training completed in 6.5438 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest with combined features...
#     Random Forest training completed in 31.6201 seconds
#     Random Forest evaluation complete
# Completed evaluation with 20 features
#
# Processing with 30 features...
#   Using top 30 features from Chi-Square...
#     Training Logistic Regression...
#     Logistic Regression training completed in 7.2471 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 30.8545 seconds
#     Random Forest evaluation complete
#   Using top 30 features from ANOVA...
#     Training Logistic Regression...
#     Logistic Regression training completed in 7.5826 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 23.8476 seconds
#     Random Forest evaluation complete
#   Using top 30 features from Mutual Information...
#     Training Logistic Regression...
#     Logistic Regression training completed in 8.3797 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 52.4381 seconds
#     Random Forest evaluation complete
#   Applying Combined feature selection...
#     Training Logistic Regression with combined features...
#     Logistic Regression training completed in 13.2586 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest with combined features...
#     Random Forest training completed in 37.2988 seconds
#     Random Forest evaluation complete
# Completed evaluation with 30 features
#
# Processing with 40 features...
#   Using top 40 features from Chi-Square...
#     Training Logistic Regression...
#     Logistic Regression training completed in 6.8341 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 36.6742 seconds
#     Random Forest evaluation complete
#   Using top 40 features from ANOVA...
#     Training Logistic Regression...
#     Logistic Regression training completed in 7.8324 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 37.1886 seconds
#     Random Forest evaluation complete
#   Using top 40 features from Mutual Information...
#     Training Logistic Regression...
#     Logistic Regression training completed in 8.0085 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 50.4349 seconds
#     Random Forest evaluation complete
#   Applying Combined feature selection...
#     Training Logistic Regression with combined features...
#     Logistic Regression training completed in 12.5761 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest with combined features...
#     Random Forest training completed in 38.8683 seconds
#     Random Forest evaluation complete
# Completed evaluation with 40 features
#
# Processing with 50 features...
#   Using top 50 features from Chi-Square...
#     Training Logistic Regression...
#     Logistic Regression training completed in 9.0435 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 47.9627 seconds
#     Random Forest evaluation complete
#   Using top 50 features from ANOVA...
#     Training Logistic Regression...
#     Logistic Regression training completed in 7.5436 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 40.3596 seconds
#     Random Forest evaluation complete
#   Using top 50 features from Mutual Information...
#     Training Logistic Regression...
#     Logistic Regression training completed in 16.7376 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 55.1560 seconds
#     Random Forest evaluation complete
#   Applying Combined feature selection...
#     Training Logistic Regression with combined features...
#     Logistic Regression training completed in 18.1954 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest with combined features...
#     Random Forest training completed in 41.0494 seconds
#     Random Forest evaluation complete
# Completed evaluation with 50 features
#
# Processing with 60 features...
#   Using top 60 features from Chi-Square...
#     Training Logistic Regression...
#     Logistic Regression training completed in 9.5687 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 47.0946 seconds
#     Random Forest evaluation complete
#   Using top 60 features from ANOVA...
#     Training Logistic Regression...
#     Logistic Regression training completed in 8.8366 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 48.3945 seconds
#     Random Forest evaluation complete
#   Using top 60 features from Mutual Information...
#     Training Logistic Regression...
#     Logistic Regression training completed in 19.4698 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 53.6484 seconds
#     Random Forest evaluation complete
#   Applying Combined feature selection...
#     Training Logistic Regression with combined features...
#     Logistic Regression training completed in 17.3329 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest with combined features...
#     Random Forest training completed in 49.0064 seconds
#     Random Forest evaluation complete
# Completed evaluation with 60 features
#
# Processing with 70 features...
#   Using top 70 features from Chi-Square...
#     Training Logistic Regression...
#     Logistic Regression training completed in 11.1717 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 47.9649 seconds
#     Random Forest evaluation complete
#   Using top 70 features from ANOVA...
#     Training Logistic Regression...
#     Logistic Regression training completed in 12.7093 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 52.6175 seconds
#     Random Forest evaluation complete
#   Using top 70 features from Mutual Information...
#     Training Logistic Regression...
#     Logistic Regression training completed in 21.7568 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 54.1540 seconds
#     Random Forest evaluation complete
#   Applying Combined feature selection...
#     Training Logistic Regression with combined features...
#     Logistic Regression training completed in 21.2410 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest with combined features...
#     Random Forest training completed in 53.9591 seconds
#     Random Forest evaluation complete
# Completed evaluation with 70 features
# All feature selection evaluations complete. Generating plots...
# Creating overall performance comparison plot...
# Displaying overall performance comparison plot...
# Creating individual model performance plots...
#   Generating plot for Logistic Regression...
#   Displaying plot for Logistic Regression...
#   Generating plot for Random Forest...
#   Displaying plot for Random Forest...
# Creating training time comparison plot...
# Displaying training time comparison plot...
# Creating model-specific training time plots...
#   Displaying training time plot for Logistic Regression...
#   Displaying training time plot for Random Forest...
# Experiment completed successfully!

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif, f_classif
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import matplotlib.pyplot as plt
import time

print("Starting DDoS detection feature selection experiment...")

# Load dataset 
print("Loading dataset...")
X = benchmark_df.drop('Label', axis=1)
y = benchmark_df['Label']
print(f"Dataset loaded: {X.shape[0]} samples with {X.shape[1]} features")

# Split data
print("Splitting data into training and test sets...")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
print(f"Training set: {X_train.shape[0]} samples, Test set: {X_test.shape[0]} samples")

# Standardize features
print("Standardizing features...")
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
print("Feature standardization complete")

print("Defining top features based on sensitivity ranking and synergistic pairs...")
# Define top features (Sensitivity Ranking + Synergistic Pairs)
top_features_sensitivity = [
    'Inbound', 'Protocol', 'URG Flag Count', 'Down/Up Ratio', 'ACK Flag Count',
    'Fwd PSH Flags', 'RST Flag Count', 'Bwd Packet Length Min', 'CWE Flag Count',
    'SYN Flag Count', 'Bwd IAT Min', 'Subflow Bwd Bytes', 'Bwd Packet Length Max',
    'Init_Win_bytes_backward', 'Bwd Header Length', 'act_data_pkt_fwd',
    'Total Length of Bwd Packets', 'Active Std', 'Active Min', 'Init_Win_bytes_forward',
    'Total Backward Packets', 'Subflow Bwd Packets', 'Fwd Packet Length Min',
    'Fwd Packet Length Max', 'Avg Bwd Segment Size', 'Bwd Packet Length Std',
    'Active Mean', 'Fwd IAT Min', 'Max Packet Length', 'Active Max',
    'Subflow Fwd Bytes', 'Subflow Fwd Packets', 'Bwd Packet Length Mean',
    'Average Packet Size', 'Idle Std', 'Total Fwd Packets', 'Avg Fwd Segment Size',
    'Fwd Packet Length Mean', 'Min Packet Length', 'Total Length of Fwd Packets',
    'Flow IAT Min', 'Fwd Packet Length Std', 'Packet Length Mean', 'Packet Length Variance',
    'Bwd IAT Mean', 'Bwd IAT Max', 'min_seg_size_forward', 'Bwd IAT Total', 'Idle Min',
    'Idle Mean', 'Bwd Packets/s', 'Packet Length Std', 'Bwd IAT Std', 'Idle Max',
    'Fwd Header Length.1', 'Fwd Header Length', 'Source Port', 'Destination Port',
    'Flow IAT Max', 'Fwd IAT Max', 'Flow Duration', 'Fwd IAT Total', 'Fwd IAT Mean',
    'Flow Bytes/s', 'Flow IAT Mean', 'Fwd Packets/s', 'Flow Packets/s', 'Flow IAT Std',
    'Fwd IAT Std', 'Bwd Avg Bulk Rate', 'Bwd Avg Packets/Bulk'
]

print(f"Sensitivity-ranked features: {len(top_features_sensitivity)} features")
print("First 5 features:", top_features_sensitivity[:5])
print("Last 5 features:", top_features_sensitivity[-5:])

synergistic_pairs = [
    ('Subflow Bwd Bytes', 'Active Min'),
    ('Bwd Packet Length Min', 'Subflow Bwd Bytes'),
    ('Active Std', 'Active Min'),
    ('Bwd IAT Min', 'Subflow Bwd Bytes'),
    ('Bwd Header Length', 'act_data_pkt_fwd'),
    ('act_data_pkt_fwd', 'Total Length of Bwd Packets'),
    ('Down/Up Ratio', 'Subflow Bwd Bytes'),
    ('Init_Win_bytes_backward', 'act_data_pkt_fwd'),
    ('Subflow Bwd Bytes', 'Init_Win_bytes_forward'),
    ('Bwd IAT Min', 'Active Std'),
    ('Down/Up Ratio', 'Active Min'),
    ('RST Flag Count', 'Subflow Bwd Bytes'),
    ('RST Flag Count', 'Active Min'),
    ('Fwd PSH Flags', 'Subflow Bwd Bytes'),
    ('SYN Flag Count', 'Subflow Bwd Bytes'),
    ('Bwd Packet Length Min', 'Active Min'),
    ('Bwd IAT Min', 'Active Min'),
    ('Bwd Packet Length Max', 'act_data_pkt_fwd'),
    ('CWE Flag Count', 'act_data_pkt_fwd'),
    ('Bwd Packet Length Max', 'Active Min')
]

# Combine individual and pairwise features into a new feature set
print("Creating GAN feature set...")
GAN_features = list(set(top_features_sensitivity + [f for pair in synergistic_pairs for f in pair]))

# Ensure we have exactly 71 features
if len(GAN_features) > 71:
    GAN_features = GAN_features[:71]
elif len(GAN_features) < 71:
    remaining_features = [f for f in X.columns if f not in GAN_features]
    GAN_features.extend(remaining_features[:71 - len(GAN_features)])
print(f"GAN feature set created with {len(GAN_features)} features")

# Initialize models
print("Initializing machine learning models...")
models = {
    'Logistic Regression': LogisticRegression(max_iter=1000),
    'Random Forest': RandomForestClassifier()
}
print(f"Initialized {len(models)} models: {', '.join(models.keys())}")

# Initialize feature selection techniques
def get_best_features_selector(method, k_features):
    if method == 'Chi-Square':
        return SelectKBest(score_func=chi2, k=k_features)
    elif method == 'ANOVA':
        return SelectKBest(score_func=f_classif, k=k_features)
    elif method == 'Mutual Information':
        return SelectKBest(score_func=mutual_info_classif, k=k_features)

# Initialize results structure
results = {
    metric: {
        method: {
            model_name: [] for model_name in models.keys()
        } for method in ['Chi-Square', 'ANOVA', 'Mutual Information', 'GAN_FS']
    } for metric in ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'AUC-ROC']
}

# Initialize training times structure
training_times = {
    method: {
        model_name: [] for model_name in models.keys()
    } for method in ['Chi-Square', 'ANOVA', 'Mutual Information', 'GAN_FS']
}

# Apply feature selection once with max features
max_features = 71
fs_outputs = {}
for fs_method in ['Chi-Square', 'ANOVA', 'Mutual Information']:
    print(f"Applying {fs_method} feature selection with {max_features} features...")
    fs = get_best_features_selector(fs_method, max_features)
    fs.fit(X_train, y_train)
    fs_outputs[fs_method] = fs

print("Feature selection outputs stored for Chi-Square, ANOVA, and Mutual Information.")

# Iterate over number of features to select
feature_counts = range(10, 71, 10)
print(f"Starting evaluation with feature counts: {list(feature_counts)}")

for k in feature_counts:
    print(f"\nProcessing with {k} features...")
    
    # For traditional feature selection methods
    for fs_method in ['Chi-Square', 'ANOVA', 'Mutual Information']:
        print(f"  Using top {k} features from {fs_method}...")
        
        # Get the indices of the top k features
        top_k_indices = fs_outputs[fs_method].scores_.argsort()[-k:][::-1]
        
        # Select the top k features
        X_train_fs = X_train[:, top_k_indices]
        X_test_fs = X_test[:, top_k_indices]
        
        for model_name, model in models.items():
            print(f"    Training {model_name}...")
            
            # Measure training time
            start_time = time.time()
            model.fit(X_train_fs, y_train)
            end_time = time.time()
            training_time = end_time - start_time
            
            # Store the training time
            training_times[fs_method][model_name].append(training_time)
            print(f"    {model_name} training completed in {training_time:.4f} seconds")
            
            y_pred = model.predict(X_test_fs)
            y_prob = model.predict_proba(X_test_fs)[:, 1]

            # Store results directly for this model
            results['Accuracy'][fs_method][model_name].append(accuracy_score(y_test, y_pred))
            results['Precision'][fs_method][model_name].append(precision_score(y_test, y_pred))
            results['Recall'][fs_method][model_name].append(recall_score(y_test, y_pred))
            results['F1 Score'][fs_method][model_name].append(f1_score(y_test, y_pred))
            results['AUC-ROC'][fs_method][model_name].append(roc_auc_score(y_test, y_prob))
            print(f"    {model_name} evaluation complete")
    
    # For GAN feature set
    print(f"  Applying GAN feature selection...")
    X_train_GAN = X_train[:, [X.columns.get_loc(f) for f in GAN_features[:k]]]
    X_test_GAN = X_test[:, [X.columns.get_loc(f) for f in GAN_features[:k]]]

    for model_name, model in models.items():
        print(f"    Training {model_name} with GAN features...")
        
        # Measure training time
        start_time = time.time()
        model.fit(X_train_GAN, y_train)
        end_time = time.time()
        training_time = end_time - start_time
        
        # Store the training time
        training_times['GAN_FS'][model_name].append(training_time)
        print(f"    {model_name} training completed in {training_time:.4f} seconds")
        
        y_pred = model.predict(X_test_GAN)
        y_prob = model.predict_proba(X_test_GAN)[:, 1]

        # Store results directly for this model
        results['Accuracy']['GAN_FS'][model_name].append(accuracy_score(y_test, y_pred))
        results['Precision']['GAN_FS'][model_name].append(precision_score(y_test, y_pred))
        results['Recall']['GAN_FS'][model_name].append(recall_score(y_test, y_pred))
        results['F1 Score']['GAN_FS'][model_name].append(f1_score(y_test, y_pred))
        results['AUC-ROC']['GAN_FS'][model_name].append(roc_auc_score(y_test, y_prob))
        print(f"    {model_name} evaluation complete")
    
    print(f"Completed evaluation with {k} features")

print("All feature selection evaluations complete. Generating plots...")

# Plotting the performance results
print("Creating overall performance comparison plot...")
plt.figure(figsize=(20, 15))
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'AUC-ROC']

for idx, metric in enumerate(metrics, 1):
    plt.subplot(len(metrics), 1, idx)
    
    for method in ['Chi-Square', 'ANOVA', 'Mutual Information', 'GAN_FS']:
        for model_name in models.keys():
            plt.plot(
                feature_counts, 
                results[metric][method][model_name], 
                label=f"{method} - {model_name}"
            )
    
    plt.title(metric)
    plt.xlabel('Number of Features')
    plt.ylabel(metric)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.xticks(feature_counts)
    plt.grid(True)

plt.tight_layout()
print("Displaying overall performance comparison plot...")
plt.show()

# One figure per model for performance metrics
print("Creating individual model performance plots...")
for model_name in models.keys():
    print(f"  Generating plot for {model_name}...")
    plt.figure(figsize=(15, 10))
    
    for idx, metric in enumerate(metrics, 1):
        plt.subplot(2, 3, idx)
        
        for method in ['Chi-Square', 'ANOVA', 'Mutual Information', 'GAN_FS']:
            plt.plot(
                feature_counts, 
                results[metric][method][model_name], 
                label=method
            )
        
        plt.title(f"{model_name} - {metric}")
        plt.xlabel('Number of Features')
        plt.ylabel(metric)
        plt.legend()
        plt.xticks(feature_counts)
    
    plt.tight_layout()
    plt.suptitle(f"Performance Metrics for {model_name}", fontsize=16)
    plt.subplots_adjust(top=0.93)
    print(f"  Displaying plot for {model_name}...")
    plt.show()

# Add plot for training times - overall comparison
print("Creating training time comparison plot...")
plt.figure(figsize=(15, 8))

for method in ['Chi-Square', 'ANOVA', 'Mutual Information', 'GAN_FS']:
    for model_name in models.keys():
        plt.plot(
            feature_counts, 
            training_times[method][model_name], 
            label=f"{method} - {model_name}",
            marker='o'
        )

plt.title("Training Time Comparison")
plt.xlabel('Number of Features')
plt.ylabel('Training Time (seconds)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(feature_counts)
plt.grid(True)
plt.tight_layout()
print("Displaying training time comparison plot...")
plt.show()

# Plot training time for each model separately
print("Creating model-specific training time plots...")
for model_name in models.keys():
    plt.figure(figsize=(10, 6))
    
    for method in ['Chi-Square', 'ANOVA', 'Mutual Information', 'GAN_FS']:
        plt.plot(
            feature_counts, 
            training_times[method][model_name], 
            label=method,
            marker='o'
        )
    
    plt.title(f"Training Time for {model_name}")
    plt.xlabel('Number of Features')
    plt.ylabel('Training Time (seconds)')
    plt.legend()
    plt.xticks(feature_counts)
    plt.grid(True)
    plt.tight_layout()
    print(f"  Displaying training time plot for {model_name}...")
    plt.show()

print("Experiment completed successfully!")
# Out:
# Starting DDoS detection feature selection experiment...
# Loading dataset...
# Dataset loaded: 827519 samples with 81 features
# Splitting data into training and test sets...
# Training set: 579263 samples, Test set: 248256 samples
# Standardizing features...
# Feature standardization complete
# Defining top features based on sensitivity ranking and synergistic pairs...
# Sensitivity-ranked features: 71 features
# First 5 features: ['Inbound', 'Protocol', 'URG Flag Count', 'Down/Up Ratio', 'ACK Flag Count']
# Last 5 features: ['Flow Packets/s', 'Flow IAT Std', 'Fwd IAT Std', 'Bwd Avg Bulk Rate', 'Bwd Avg Packets/Bulk']
# Creating combined feature set...
# Combined feature set created with 71 features
# Initializing machine learning models...
# Initialized 2 models: Logistic Regression, Random Forest
# Applying Chi-Square feature selection with 41 features...
# Applying ANOVA feature selection with 41 features...
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:114: UserWarning: Features [33 34 35 45 48 52 58 59 60 61 62 63] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# Applying Mutual Information feature selection with 41 features...
# Feature selection outputs stored for Chi-Square, ANOVA, and Mutual Information.
# Starting evaluation with feature counts: [10, 20, 30, 40]
#
# Processing with 10 features...
#   Using top 10 features from Chi-Square...
#     Training Logistic Regression...
#     Logistic Regression training completed in 0.5943 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 7.4201 seconds
#     Random Forest evaluation complete
#   Using top 10 features from ANOVA...
#     Training Logistic Regression...
#     Logistic Regression training completed in 0.5683 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 7.7441 seconds
#     Random Forest evaluation complete
#   Using top 10 features from Mutual Information...
#     Training Logistic Regression...
#     Logistic Regression training completed in 3.4495 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 45.0487 seconds
#     Random Forest evaluation complete
#   Applying Combined feature selection...
#     Training Logistic Regression with combined features...
#     Logistic Regression training completed in 4.1593 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest with combined features...
#     Random Forest training completed in 28.2803 seconds
#     Random Forest evaluation complete
# Completed evaluation with 10 features
#
# Processing with 20 features...
#   Using top 20 features from Chi-Square...
#     Training Logistic Regression...
#     Logistic Regression training completed in 4.4075 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 26.5179 seconds
#     Random Forest evaluation complete
#   Using top 20 features from ANOVA...
#     Training Logistic Regression...
#     Logistic Regression training completed in 3.8455 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 10.4642 seconds
#     Random Forest evaluation complete
#   Using top 20 features from Mutual Information...
#     Training Logistic Regression...
#     Logistic Regression training completed in 7.0925 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 50.0927 seconds
#     Random Forest evaluation complete
#   Applying Combined feature selection...
#     Training Logistic Regression with combined features...
#     Logistic Regression training completed in 7.0196 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest with combined features...
#     Random Forest training completed in 32.2190 seconds
#     Random Forest evaluation complete
# Completed evaluation with 20 features
#
# Processing with 30 features...
#   Using top 30 features from Chi-Square...
#     Training Logistic Regression...
#     Logistic Regression training completed in 6.7910 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 29.7479 seconds
#     Random Forest evaluation complete
#   Using top 30 features from ANOVA...
#     Training Logistic Regression...
#     Logistic Regression training completed in 7.6221 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 22.4506 seconds
#     Random Forest evaluation complete
#   Using top 30 features from Mutual Information...
#     Training Logistic Regression...
#     Logistic Regression training completed in 8.2864 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 57.2538 seconds
#     Random Forest evaluation complete
#   Applying Combined feature selection...
#     Training Logistic Regression with combined features...
#     Logistic Regression training completed in 13.3364 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest with combined features...
#     Random Forest training completed in 35.9841 seconds
#     Random Forest evaluation complete
# Completed evaluation with 30 features
#
# Processing with 40 features...
#   Using top 40 features from Chi-Square...
#     Training Logistic Regression...
#     Logistic Regression training completed in 6.8123 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 35.5020 seconds
#     Random Forest evaluation complete
#   Using top 40 features from ANOVA...
#     Training Logistic Regression...
#     Logistic Regression training completed in 7.8338 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 35.8679 seconds
#     Random Forest evaluation complete
#   Using top 40 features from Mutual Information...
#     Training Logistic Regression...
#     Logistic Regression training completed in 8.0639 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest training completed in 52.2185 seconds
#     Random Forest evaluation complete
#   Applying Combined feature selection...
#     Training Logistic Regression with combined features...
#     Logistic Regression training completed in 13.0951 seconds
#     Logistic Regression evaluation complete
#     Training Random Forest with combined features...
#     Random Forest training completed in 41.3634 seconds
#     Random Forest evaluation complete
# Completed evaluation with 40 features
# All feature selection evaluations complete. Generating plots...
# Creating overall performance comparison plot...
# Displaying overall performance comparison plot...
# Creating individual model performance plots...
#   Generating plot for Logistic Regression...
#   Displaying plot for Logistic Regression...
#   Generating plot for Random Forest...
#   Displaying plot for Random Forest...
# Creating training time comparison plot...
# Displaying training time comparison plot...
# Creating model-specific training time plots...
#   Displaying training time plot for Logistic Regression...
#   Displaying training time plot for Random Forest...
# Experiment completed successfully!

# %%
# import numpy as np
# import pandas as pd
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import MinMaxScaler
# from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif, f_classif
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.linear_model import LogisticRegression
# from sklearn.svm import SVC
# from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
# import matplotlib.pyplot as plt

# print("Starting DDoS detection feature selection experiment...")

# # Load dataset 
# print("Loading dataset...")
# X = benchmark_df.drop('Label', axis=1)
# y = benchmark_df['Label']
# print(f"Dataset loaded: {X.shape[0]} samples with {X.shape[1]} features")

# # Split data
# print("Splitting data into training and test sets...")
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# print(f"Training set: {X_train.shape[0]} samples, Test set: {X_test.shape[0]} samples")

# # Standardize features
# print("Standardizing features...")
# scaler = MinMaxScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.transform(X_test)
# print("Feature standardization complete")

# print("Defining top features based on sensitivity ranking and synergistic pairs...")
# # Define top features (Sensitivity Ranking + Synergistic Pairs)
# top_features_sensitivity = [
#     'Inbound', 'Protocol', 'URG Flag Count', 'Down/Up Ratio', 'ACK Flag Count',
#     'Fwd PSH Flags', 'RST Flag Count', 'Bwd Packet Length Min', 'CWE Flag Count',
#     'SYN Flag Count', 'Bwd IAT Min', 'Subflow Bwd Bytes', 'Bwd Packet Length Max',
#     'Init_Win_bytes_backward', 'Bwd Header Length', 'act_data_pkt_fwd',
#     'Total Length of Bwd Packets', 'Active Std', 'Active Min', 'Init_Win_bytes_forward',
#     'Total Backward Packets', 'Subflow Bwd Packets', 'Fwd Packet Length Min',
#     'Fwd Packet Length Max', 'Avg Bwd Segment Size', 'Bwd Packet Length Std',
#     'Active Mean', 'Fwd IAT Min', 'Max Packet Length', 'Active Max',
#     'Subflow Fwd Bytes', 'Subflow Fwd Packets', 'Bwd Packet Length Mean',
#     'Average Packet Size', 'Idle Std', 'Total Fwd Packets', 'Avg Fwd Segment Size',
#     'Fwd Packet Length Mean', 'Min Packet Length', 'Total Length of Fwd Packets',
#     'Flow IAT Min', 'Fwd Packet Length Std', 'Packet Length Mean', 'Packet Length Variance',
#     'Bwd IAT Mean', 'Bwd IAT Max', 'min_seg_size_forward', 'Bwd IAT Total', 'Idle Min',
#     'Idle Mean', 'Bwd Packets/s', 'Packet Length Std', 'Bwd IAT Std', 'Idle Max',
#     'Fwd Header Length.1', 'Fwd Header Length', 'Source Port', 'Destination Port',
#     'Flow IAT Max', 'Fwd IAT Max', 'Flow Duration', 'Fwd IAT Total', 'Fwd IAT Mean',
#     'Flow Bytes/s', 'Flow IAT Mean', 'Fwd Packets/s', 'Flow Packets/s', 'Flow IAT Std',
#     'Fwd IAT Std', 'Bwd Avg Bulk Rate', 'Bwd Avg Packets/Bulk'
# ]

# print(f"Sensitivity-ranked features: {len(top_features_sensitivity)} features")
# print("First 5 features:", top_features_sensitivity[:5])
# print("Last 5 features:", top_features_sensitivity[-5:])

# synergistic_pairs = [
#     ('Subflow Bwd Bytes', 'Active Min'),
#     ('Bwd Packet Length Min', 'Subflow Bwd Bytes'),
#     ('Active Std', 'Active Min'),
#     ('Bwd IAT Min', 'Subflow Bwd Bytes'),
#     ('Bwd Header Length', 'act_data_pkt_fwd'),
#     ('act_data_pkt_fwd', 'Total Length of Bwd Packets'),
#     ('Down/Up Ratio', 'Subflow Bwd Bytes'),
#     ('Init_Win_bytes_backward', 'act_data_pkt_fwd'),
#     ('Subflow Bwd Bytes', 'Init_Win_bytes_forward'),
#     ('Bwd IAT Min', 'Active Std'),
#     ('Down/Up Ratio', 'Active Min'),
#     ('RST Flag Count', 'Subflow Bwd Bytes'),
#     ('RST Flag Count', 'Active Min'),
#     ('Fwd PSH Flags', 'Subflow Bwd Bytes'),
#     ('SYN Flag Count', 'Subflow Bwd Bytes'),
#     ('Bwd Packet Length Min', 'Active Min'),
#     ('Bwd IAT Min', 'Active Min'),
#     ('Bwd Packet Length Max', 'act_data_pkt_fwd'),
#     ('CWE Flag Count', 'act_data_pkt_fwd'),
#     ('Bwd Packet Length Max', 'Active Min')
# ]

# # Combine individual and pairwise features into a new feature set
# print("Creating GAN feature set...")
# GAN_features = list(set(top_features_sensitivity + [f for pair in synergistic_pairs for f in pair]))

# # Ensure we have exactly 71 features
# if len(GAN_features) > 71:
#     GAN_features = GAN_features[:71]
# elif len(GAN_features) < 71:
#     remaining_features = [f for f in X.columns if f not in GAN_features]
#     GAN_features.extend(remaining_features[:71 - len(GAN_features)])
# print(f"GAN feature set created with {len(GAN_features)} features")

# # Initialize models
# print("Initializing machine learning models...")
# models = {
#     'Logistic Regression': LogisticRegression(max_iter=1000),
#     'Random Forest': RandomForestClassifier()
#     # 'Support Vector Machine': SVC(probability=True)
# }
# print(f"Initialized {len(models)} models: {', '.join(models.keys())}")

# # Initialize feature selection techniques
# def get_best_features_selector(method, k_features):
#     if method == 'Chi-Square':
#         return SelectKBest(score_func=chi2, k=k_features)
#     elif method == 'ANOVA':
#         return SelectKBest(score_func=f_classif, k=k_features)
#     elif method == 'Mutual Information':
#         return SelectKBest(score_func=mutual_info_classif, k=k_features)

# # Initialize a more detailed results structure
# results = {
#     metric: {
#         method: {
#             model_name: [] for model_name in models.keys()
#         } for method in ['Chi-Square', 'ANOVA', 'Mutual Information', 'GAN_FS']
#     } for metric in ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'AUC-ROC']
# }

# # Iterate over number of features to select
# feature_counts = range(10, 41, 10)
# print(f"Starting evaluation with feature counts: {list(feature_counts)}")

# for k in feature_counts:
#     print(f"\nProcessing with {k} features...")
    
#     # For traditional feature selection methods
#     for fs_method in ['Chi-Square', 'ANOVA', 'Mutual Information']:
#         print(f"  Applying {fs_method} feature selection...")
#         fs = get_best_features_selector(fs_method, k)
        
#         X_train_fs = fs.fit_transform(X_train, y_train)
#         X_test_fs = fs.transform(X_test)
        
#         for model_name, model in models.items():
#             print(f"    Training {model_name}...")
#             model.fit(X_train_fs, y_train)
#             y_pred = model.predict(X_test_fs)
#             y_prob = model.predict_proba(X_test_fs)[:, 1]

#             # Store results directly for this model
#             results['Accuracy'][fs_method][model_name].append(accuracy_score(y_test, y_pred))
#             results['Precision'][fs_method][model_name].append(precision_score(y_test, y_pred))
#             results['Recall'][fs_method][model_name].append(recall_score(y_test, y_pred))
#             results['F1 Score'][fs_method][model_name].append(f1_score(y_test, y_pred))
#             results['AUC-ROC'][fs_method][model_name].append(roc_auc_score(y_test, y_prob))
#             print(f"    {model_name} evaluation complete")
        
#         print(f"  {fs_method} feature selection complete")

#     # For GAN feature set
#     print(f"  Applying GAN feature selection...")
#     X_train_GAN = X_train[:, [X.columns.get_loc(f) for f in GAN_features[:k]]]
#     X_test_GAN = X_test[:, [X.columns.get_loc(f) for f in GAN_features[:k]]]

#     for model_name, model in models.items():
#         print(f"    Training {model_name} with GAN features...")
#         model.fit(X_train_GAN, y_train)
#         y_pred = model.predict(X_test_GAN)
#         y_prob = model.predict_proba(X_test_GAN)[:, 1]

#         # Store results directly for this model
#         results['Accuracy']['GAN_FS'][model_name].append(accuracy_score(y_test, y_pred))
#         results['Precision']['GAN_FS'][model_name].append(precision_score(y_test, y_pred))
#         results['Recall']['GAN_FS'][model_name].append(recall_score(y_test, y_pred))
#         results['F1 Score']['GAN_FS'][model_name].append(f1_score(y_test, y_pred))
#         results['AUC-ROC']['GAN_FS'][model_name].append(roc_auc_score(y_test, y_prob))
#         print(f"    {model_name} evaluation complete")

#     print(f"Completed evaluation with {k} features")

# print("All feature selection evaluations complete. Generating plots...")

# # Plotting the results
# print("Creating overall performance comparison plot...")
# plt.figure(figsize=(20, 15))
# metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'AUC-ROC']

# for idx, metric in enumerate(metrics, 1):
#     plt.subplot(len(metrics), 1, idx)
    
#     for method in ['Chi-Square', 'ANOVA', 'Mutual Information', 'GAN_FS']:
#         for model_name in models.keys():
#             plt.plot(
#                 feature_counts, 
#                 results[metric][method][model_name], 
#                 label=f"{method} - {model_name}"
#             )
    
#     plt.title(metric)
#     plt.xlabel('Number of Features')
#     plt.ylabel(metric)
#     plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
#     plt.xticks(feature_counts)
#     plt.grid(True)

# plt.tight_layout()
# print("Displaying overall performance comparison plot...")
# plt.show()

# # One figure per model
# print("Creating individual model performance plots...")
# for model_name in models.keys():
#     print(f"  Generating plot for {model_name}...")
#     plt.figure(figsize=(15, 10))
    
#     for idx, metric in enumerate(metrics, 1):
#         plt.subplot(2, 3, idx)
        
#         for method in ['Chi-Square', 'ANOVA', 'Mutual Information', 'GAN_FS']:
#             plt.plot(
#                 feature_counts, 
#                 results[metric][method][model_name], 
#                 label=method
#             )
        
#         plt.title(f"{model_name} - {metric}")
#         plt.xlabel('Number of Features')
#         plt.ylabel(metric)
#         plt.legend()
#         plt.xticks(feature_counts)
    
#     plt.tight_layout()
#     plt.suptitle(f"Performance Metrics for {model_name}", fontsize=16)
#     plt.subplots_adjust(top=0.93)
#     print(f"  Displaying plot for {model_name}...")
#     plt.show()

# print("Experiment completed successfully!")
# Out:
# Starting DDoS detection feature selection experiment...
# Loading dataset...
# Dataset loaded: 827519 samples with 81 features
# Splitting data into training and test sets...
# Training set: 579263 samples, Test set: 248256 samples
# Standardizing features...
# Feature standardization complete
# Defining top features based on sensitivity ranking and synergistic pairs...
# Sensitivity-ranked features: 71 features
# First 5 features: ['Inbound', 'Protocol', 'URG Flag Count', 'Down/Up Ratio', 'ACK Flag Count']
# Last 5 features: ['Flow Packets/s', 'Flow IAT Std', 'Fwd IAT Std', 'Bwd Avg Bulk Rate', 'Bwd Avg Packets/Bulk']
# Creating combined feature set...
# Combined feature set created with 71 features
# Initializing machine learning models...
# Initialized 3 models: Logistic Regression, Random Forest, Support Vector Machine
# Starting evaluation with feature counts: [10, 20, 30, 40, 50, 60, 70]
#
# Processing with 10 features...
#   Applying Chi-Square feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...

# %%
# import numpy as np
# import pandas as pd
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import MinMaxScaler
# from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif, f_classif
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.linear_model import LogisticRegression
# from sklearn.svm import SVC
# from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
# import matplotlib.pyplot as plt

# print("Starting DDoS detection feature selection experiment...")

# # Load dataset 
# print("Loading dataset...")
# X = benchmark_df.drop('Label', axis=1)
# y = benchmark_df['Label']
# print(f"Dataset loaded: {X.shape[0]} samples with {X.shape[1]} features")

# # Split data
# print("Splitting data into training and test sets...")
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# print(f"Training set: {X_train.shape[0]} samples, Test set: {X_test.shape[0]} samples")

# # Standardize features
# print("Standardizing features...")
# scaler = MinMaxScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.transform(X_test)
# print("Feature standardization complete")

# print("Defining top features based on sensitivity ranking and synergistic pairs...")
# # Define top features (Sensitivity Ranking + Synergistic Pairs)
# top_features_sensitivity = [
#     'Inbound', 'Protocol', 'URG Flag Count', 'Down/Up Ratio', 'ACK Flag Count',
#     'Fwd PSH Flags', 'RST Flag Count', 'Bwd Packet Length Min', 'CWE Flag Count',
#     'SYN Flag Count', 'Bwd IAT Min', 'Subflow Bwd Bytes', 'Bwd Packet Length Max',
#     'Init_Win_bytes_backward', 'Bwd Header Length', 'act_data_pkt_fwd',
#     'Total Length of Bwd Packets', 'Active Std', 'Active Min', 'Init_Win_bytes_forward',
#     'Total Backward Packets', 'Subflow Bwd Packets', 'Fwd Packet Length Min',
#     'Fwd Packet Length Max', 'Avg Bwd Segment Size', 'Bwd Packet Length Std',
#     'Active Mean', 'Fwd IAT Min', 'Max Packet Length', 'Active Max',
#     'Subflow Fwd Bytes', 'Subflow Fwd Packets', 'Bwd Packet Length Mean',
#     'Average Packet Size', 'Idle Std', 'Total Fwd Packets', 'Avg Fwd Segment Size',
#     'Fwd Packet Length Mean', 'Min Packet Length', 'Total Length of Fwd Packets',
#     'Flow IAT Min', 'Fwd Packet Length Std', 'Packet Length Mean', 'Packet Length Variance',
#     'Bwd IAT Mean', 'Bwd IAT Max', 'min_seg_size_forward', 'Bwd IAT Total', 'Idle Min',
#     'Idle Mean', 'Bwd Packets/s', 'Packet Length Std', 'Bwd IAT Std', 'Idle Max',
#     'Fwd Header Length.1', 'Fwd Header Length', 'Source Port', 'Destination Port',
#     'Flow IAT Max', 'Fwd IAT Max', 'Flow Duration', 'Fwd IAT Total', 'Fwd IAT Mean',
#     'Flow Bytes/s', 'Flow IAT Mean', 'Fwd Packets/s', 'Flow Packets/s', 'Flow IAT Std',
#     'Fwd IAT Std', 'Bwd Avg Bulk Rate', 'Bwd Avg Packets/Bulk'
# ]

# print(f"Sensitivity-ranked features: {len(top_features_sensitivity)} features")
# print("First 5 features:", top_features_sensitivity[:5])
# print("Last 5 features:", top_features_sensitivity[-5:])

# synergistic_pairs = [
#     ('Subflow Bwd Bytes', 'Active Min'),
#     ('Bwd Packet Length Min', 'Subflow Bwd Bytes'),
#     ('Active Std', 'Active Min'),
#     ('Bwd IAT Min', 'Subflow Bwd Bytes'),
#     ('Bwd Header Length', 'act_data_pkt_fwd'),
#     ('act_data_pkt_fwd', 'Total Length of Bwd Packets'),
#     ('Down/Up Ratio', 'Subflow Bwd Bytes'),
#     ('Init_Win_bytes_backward', 'act_data_pkt_fwd'),
#     ('Subflow Bwd Bytes', 'Init_Win_bytes_forward'),
#     ('Bwd IAT Min', 'Active Std'),
#     ('Down/Up Ratio', 'Active Min'),
#     ('RST Flag Count', 'Subflow Bwd Bytes'),
#     ('RST Flag Count', 'Active Min'),
#     ('Fwd PSH Flags', 'Subflow Bwd Bytes'),
#     ('SYN Flag Count', 'Subflow Bwd Bytes'),
#     ('Bwd Packet Length Min', 'Active Min'),
#     ('Bwd IAT Min', 'Active Min'),
#     ('Bwd Packet Length Max', 'act_data_pkt_fwd'),
#     ('CWE Flag Count', 'act_data_pkt_fwd'),
#     ('Bwd Packet Length Max', 'Active Min')
# ]

# # Combine individual and pairwise features into a new feature set
# print("Creating GAN feature set...")
# GAN_features = list(set(top_features_sensitivity + [f for pair in synergistic_pairs for f in pair]))

# # Ensure we have exactly 71 features
# if len(GAN_features) > 71:
#     GAN_features = GAN_features[:71]
# elif len(GAN_features) < 71:
#     remaining_features = [f for f in X.columns if f not in GAN_features]
#     GAN_features.extend(remaining_features[:71 - len(GAN_features)])
# print(f"GAN feature set created with {len(GAN_features)} features")

# # Initialize models
# print("Initializing machine learning models...")
# models = {
#     'Logistic Regression': LogisticRegression(max_iter=1000),
#     'Random Forest': RandomForestClassifier(),
#     'Support Vector Machine': SVC(probability=True)
# }
# print(f"Initialized {len(models)} models: {', '.join(models.keys())}")

# # Initialize feature selection techniques
# def get_best_features_selector(method, k_features):
#     if method == 'Chi-Square':
#         return SelectKBest(score_func=chi2, k=k_features)
#     elif method == 'ANOVA':
#         return SelectKBest(score_func=f_classif, k=k_features)
#     elif method == 'Mutual Information':
#         return SelectKBest(score_func=mutual_info_classif, k=k_features)

# # Initialize a more detailed results structure
# results = {
#     metric: {
#         method: {
#             model_name: [] for model_name in models.keys()
#         } for method in ['Chi-Square', 'ANOVA', 'Mutual Information', 'GAN_FS']
#     } for metric in ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'AUC-ROC']
# }

# # Iterate over number of features to select
# feature_counts = range(10, 71, 10)
# print(f"Starting evaluation with feature counts: {list(feature_counts)}")

# for k in feature_counts:
#     print(f"\nProcessing with {k} features...")
    
#     # For traditional feature selection methods
#     for fs_method in ['Chi-Square', 'ANOVA', 'Mutual Information']:
#         print(f"  Applying {fs_method} feature selection...")
#         fs = get_best_features_selector(fs_method, k)
        
#         X_train_fs = fs.fit_transform(X_train, y_train)
#         X_test_fs = fs.transform(X_test)
        
#         for model_name, model in models.items():
#             print(f"    Training {model_name}...")
#             model.fit(X_train_fs, y_train)
#             y_pred = model.predict(X_test_fs)
#             y_prob = model.predict_proba(X_test_fs)[:, 1]

#             # Store results directly for this model
#             results['Accuracy'][fs_method][model_name].append(accuracy_score(y_test, y_pred))
#             results['Precision'][fs_method][model_name].append(precision_score(y_test, y_pred))
#             results['Recall'][fs_method][model_name].append(recall_score(y_test, y_pred))
#             results['F1 Score'][fs_method][model_name].append(f1_score(y_test, y_pred))
#             results['AUC-ROC'][fs_method][model_name].append(roc_auc_score(y_test, y_prob))
#             print(f"    {model_name} evaluation complete")
        
#         print(f"  {fs_method} feature selection complete")

#     # For GAN feature set
#     print(f"  Applying GAN feature selection...")
#     X_train_GAN = X_train[:, [X.columns.get_loc(f) for f in GAN_features[:k]]]
#     X_test_GAN = X_test[:, [X.columns.get_loc(f) for f in GAN_features[:k]]]

#     for model_name, model in models.items():
#         print(f"    Training {model_name} with GAN features...")
#         model.fit(X_train_GAN, y_train)
#         y_pred = model.predict(X_test_GAN)
#         y_prob = model.predict_proba(X_test_GAN)[:, 1]

#         # Store results directly for this model
#         results['Accuracy']['GAN_FS'][model_name].append(accuracy_score(y_test, y_pred))
#         results['Precision']['GAN_FS'][model_name].append(precision_score(y_test, y_pred))
#         results['Recall']['GAN_FS'][model_name].append(recall_score(y_test, y_pred))
#         results['F1 Score']['GAN_FS'][model_name].append(f1_score(y_test, y_pred))
#         results['AUC-ROC']['GAN_FS'][model_name].append(roc_auc_score(y_test, y_prob))
#         print(f"    {model_name} evaluation complete")

#     print(f"Completed evaluation with {k} features")

# print("All feature selection evaluations complete. Generating plots...")

# # Plotting the results
# print("Creating overall performance comparison plot...")
# plt.figure(figsize=(20, 15))
# metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'AUC-ROC']

# for idx, metric in enumerate(metrics, 1):
#     plt.subplot(len(metrics), 1, idx)
    
#     for method in ['Chi-Square', 'ANOVA', 'Mutual Information', 'GAN_FS']:
#         for model_name in models.keys():
#             plt.plot(
#                 feature_counts, 
#                 results[metric][method][model_name], 
#                 label=f"{method} - {model_name}"
#             )
    
#     plt.title(metric)
#     plt.xlabel('Number of Features')
#     plt.ylabel(metric)
#     plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
#     plt.xticks(feature_counts)
#     plt.grid(True)

# plt.tight_layout()
# print("Displaying overall performance comparison plot...")
# plt.show()

# # One figure per model
# print("Creating individual model performance plots...")
# for model_name in models.keys():
#     print(f"  Generating plot for {model_name}...")
#     plt.figure(figsize=(15, 10))
    
#     for idx, metric in enumerate(metrics, 1):
#         plt.subplot(2, 3, idx)
        
#         for method in ['Chi-Square', 'ANOVA', 'Mutual Information', 'GAN_FS']:
#             plt.plot(
#                 feature_counts, 
#                 results[metric][method][model_name], 
#                 label=method
#             )
        
#         plt.title(f"{model_name} - {metric}")
#         plt.xlabel('Number of Features')
#         plt.ylabel(metric)
#         plt.legend()
#         plt.xticks(feature_counts)
    
#     plt.tight_layout()
#     plt.suptitle(f"Performance Metrics for {model_name}", fontsize=16)
#     plt.subplots_adjust(top=0.93)
#     print(f"  Displaying plot for {model_name}...")
#     plt.show()

# print("Experiment completed successfully!")
# Out:
# Starting DDoS detection feature selection experiment...
# Loading dataset...
# Dataset loaded: 103154 samples with 81 features
# Splitting data into training and test sets...
# Training set: 72207 samples, Test set: 30947 samples
# Standardizing features...
# Feature standardization complete
# Defining top features based on sensitivity ranking and synergistic pairs...
# Sensitivity-ranked features: 71 features
# First 5 features: ['Inbound', 'Protocol', 'URG Flag Count', 'Down/Up Ratio', 'ACK Flag Count']
# Last 5 features: ['Flow Packets/s', 'Flow IAT Std', 'Fwd IAT Std', 'Bwd Avg Bulk Rate', 'Bwd Avg Packets/Bulk']
# Creating combined feature set...
# Combined feature set created with 71 features
# Initializing machine learning models...
# Initialized 3 models: Logistic Regression, Random Forest, Support Vector Machine
# Starting evaluation with feature counts: [10, 20, 30, 40, 50, 60, 70]
#
# Processing with 10 features...
#   Applying Chi-Square feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Chi-Square feature selection complete
#   Applying ANOVA feature selection...
#     Training Logistic Regression...
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:114: UserWarning: Features [33 34 35 45 48 52 58 59 60 61 62 63] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   ANOVA feature selection complete
#   Applying Mutual Information feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Mutual Information feature selection complete
#   Applying Combined feature selection...
#     Training Logistic Regression with combined features...
#     Logistic Regression evaluation complete
#     Training Random Forest with combined features...
#     Random Forest evaluation complete
#     Training Support Vector Machine with combined features...
#     Support Vector Machine evaluation complete
# Completed evaluation with 10 features
#
# Processing with 20 features...
#   Applying Chi-Square feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Chi-Square feature selection complete
#   Applying ANOVA feature selection...
#     Training Logistic Regression...
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:114: UserWarning: Features [33 34 35 45 48 52 58 59 60 61 62 63] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   ANOVA feature selection complete
#   Applying Mutual Information feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Mutual Information feature selection complete
#   Applying Combined feature selection...
#     Training Logistic Regression with combined features...
#     Logistic Regression evaluation complete
#     Training Random Forest with combined features...
#     Random Forest evaluation complete
#     Training Support Vector Machine with combined features...
#     Support Vector Machine evaluation complete
# Completed evaluation with 20 features
#
# Processing with 30 features...
#   Applying Chi-Square feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Chi-Square feature selection complete
#   Applying ANOVA feature selection...
#     Training Logistic Regression...
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:114: UserWarning: Features [33 34 35 45 48 52 58 59 60 61 62 63] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   ANOVA feature selection complete
#   Applying Mutual Information feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Mutual Information feature selection complete
#   Applying Combined feature selection...
#     Training Logistic Regression with combined features...
#     Logistic Regression evaluation complete
#     Training Random Forest with combined features...
#     Random Forest evaluation complete
#     Training Support Vector Machine with combined features...
#     Support Vector Machine evaluation complete
# Completed evaluation with 30 features
#
# Processing with 40 features...
#   Applying Chi-Square feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Chi-Square feature selection complete
#   Applying ANOVA feature selection...
#     Training Logistic Regression...
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:114: UserWarning: Features [33 34 35 45 48 52 58 59 60 61 62 63] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   ANOVA feature selection complete
#   Applying Mutual Information feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Mutual Information feature selection complete
#   Applying Combined feature selection...
#     Training Logistic Regression with combined features...
#     Logistic Regression evaluation complete
#     Training Random Forest with combined features...
#     Random Forest evaluation complete
#     Training Support Vector Machine with combined features...
#     Support Vector Machine evaluation complete
# Completed evaluation with 40 features
#
# Processing with 50 features...
#   Applying Chi-Square feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Chi-Square feature selection complete
#   Applying ANOVA feature selection...
#     Training Logistic Regression...
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:114: UserWarning: Features [33 34 35 45 48 52 58 59 60 61 62 63] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   ANOVA feature selection complete
#   Applying Mutual Information feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Mutual Information feature selection complete
#   Applying Combined feature selection...
#     Training Logistic Regression with combined features...
#     Logistic Regression evaluation complete
#     Training Random Forest with combined features...
#     Random Forest evaluation complete
#     Training Support Vector Machine with combined features...
#     Support Vector Machine evaluation complete
# Completed evaluation with 50 features
#
# Processing with 60 features...
#   Applying Chi-Square feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Chi-Square feature selection complete
#   Applying ANOVA feature selection...
#     Training Logistic Regression...
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:114: UserWarning: Features [33 34 35 45 48 52 58 59 60 61 62 63] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   ANOVA feature selection complete
#   Applying Mutual Information feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Mutual Information feature selection complete
#   Applying Combined feature selection...
#     Training Logistic Regression with combined features...
#     Logistic Regression evaluation complete
#     Training Random Forest with combined features...
#     Random Forest evaluation complete
#     Training Support Vector Machine with combined features...
#     Support Vector Machine evaluation complete
# Completed evaluation with 60 features
#
# Processing with 70 features...
#   Applying Chi-Square feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Chi-Square feature selection complete
#   Applying ANOVA feature selection...
#     Training Logistic Regression...
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:114: UserWarning: Features [33 34 35 45 48 52 58 59 60 61 62 63] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   ANOVA feature selection complete
#   Applying Mutual Information feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Mutual Information feature selection complete
#   Applying Combined feature selection...
#     Training Logistic Regression with combined features...
#     Logistic Regression evaluation complete
#     Training Random Forest with combined features...
#     Random Forest evaluation complete
#     Training Support Vector Machine with combined features...
#     Support Vector Machine evaluation complete
# Completed evaluation with 70 features
# All feature selection evaluations complete. Generating plots...
# Creating overall performance comparison plot...
# Displaying overall performance comparison plot...
# Creating individual model performance plots...
#   Generating plot for Logistic Regression...
#   Displaying plot for Logistic Regression...
#   Generating plot for Random Forest...
#   Displaying plot for Random Forest...
#   Generating plot for Support Vector Machine...
#   Displaying plot for Support Vector Machine...
# Experiment completed successfully!

# %%
# import numpy as np
# import pandas as pd
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import MinMaxScaler
# from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif, f_classif
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.linear_model import LogisticRegression
# from sklearn.svm import SVC
# from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
# import matplotlib.pyplot as plt
 
# print("Starting DDoS detection feature selection experiment...")

# # Load dataset 
# print("Loading dataset...")
# X = benchmark_df.drop('Label', axis=1)
# y = benchmark_df['Label']
# print(f"Dataset loaded: {X.shape[0]} samples with {X.shape[1]} features")

# # Split data
# print("Splitting data into training and test sets...")
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# print(f"Training set: {X_train.shape[0]} samples, Test set: {X_test.shape[0]} samples")

# # Standardize features
# print("Standardizing features...")
# scaler = MinMaxScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.transform(X_test)
# print("Feature standardization complete")

# print("Defining top features based on sensitivity ranking and synergistic pairs...")
# # Define top features (Sensitivity Ranking + Synergistic Pairs)
# top_features_sensitivity = [
#     'Inbound', 'Protocol', 'URG Flag Count', 'Down/Up Ratio', 'ACK Flag Count',
#     'Fwd PSH Flags', 'RST Flag Count', 'Bwd Packet Length Min', 'CWE Flag Count',
#     'SYN Flag Count', 'Bwd IAT Min', 'Subflow Bwd Bytes', 'Bwd Packet Length Max',
#     'Init_Win_bytes_backward', 'Bwd Header Length', 'act_data_pkt_fwd',
#     'Total Length of Bwd Packets', 'Active Std', 'Active Min', 'Init_Win_bytes_forward',
#     'Total Backward Packets', 'Subflow Bwd Packets', 'Fwd Packet Length Min',
#     'Fwd Packet Length Max', 'Avg Bwd Segment Size', 'Bwd Packet Length Std',
#     'Active Mean', 'Fwd IAT Min', 'Max Packet Length', 'Active Max'
# ]

# synergistic_pairs = [
#     ('Subflow Bwd Bytes', 'Active Min'),
#     ('Bwd Packet Length Min', 'Subflow Bwd Bytes'),
#     ('Active Std', 'Active Min'),
#     ('Bwd IAT Min', 'Subflow Bwd Bytes'),
#     ('Bwd Header Length', 'act_data_pkt_fwd'),
#     ('act_data_pkt_fwd', 'Total Length of Bwd Packets'),
#     ('Down/Up Ratio', 'Subflow Bwd Bytes'),
#     ('Init_Win_bytes_backward', 'act_data_pkt_fwd'),
#     ('Subflow Bwd Bytes', 'Init_Win_bytes_forward'),
#     ('Bwd IAT Min', 'Active Std'),
#     ('Down/Up Ratio', 'Active Min'),
#     ('RST Flag Count', 'Subflow Bwd Bytes'),
#     ('RST Flag Count', 'Active Min'),
#     ('Fwd PSH Flags', 'Subflow Bwd Bytes'),
#     ('SYN Flag Count', 'Subflow Bwd Bytes'),
#     ('Bwd Packet Length Min', 'Active Min'),
#     ('Bwd IAT Min', 'Active Min'),
#     ('Bwd Packet Length Max', 'act_data_pkt_fwd'),
#     ('CWE Flag Count', 'act_data_pkt_fwd'),
#     ('Bwd Packet Length Max', 'Active Min')
# ]

# # Combine individual and pairwise features into a new feature set
# print("Creating GAN feature set...")
# GAN_features = list(set(top_features_sensitivity + [f for pair in synergistic_pairs for f in pair]))

# # Ensure we have exactly 71 features
# if len(GAN_features) > 71:
#     GAN_features = GAN_features[:71]
# elif len(GAN_features) < 71:
#     remaining_features = [f for f in X.columns if f not in GAN_features]
#     GAN_features.extend(remaining_features[:71 - len(GAN_features)])
# print(f"GAN feature set created with {len(GAN_features)} features")

# # Initialize models
# print("Initializing machine learning models...")
# models = {
#     'Logistic Regression': LogisticRegression(max_iter=1000),
#     'Random Forest': RandomForestClassifier(),
#     'Support Vector Machine': SVC(probability=True)
# }
# print(f"Initialized {len(models)} models: {', '.join(models.keys())}")

# # Initialize feature selection techniques
# def get_best_features_selector(method, k_features):
#     if method == 'Chi-Square':
#         return SelectKBest(score_func=chi2, k=k_features)
#     elif method == 'ANOVA':
#         return SelectKBest(score_func=f_classif, k=k_features)
#     elif method == 'Mutual Information':
#         return SelectKBest(score_func=mutual_info_classif, k=k_features)

# # List to store results
# results = {metric: {method: [] for method in ['Chi-Square', 'ANOVA', 'Mutual Information', 'GAN_FS']} for metric in ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'AUC-ROC']}

# # Iterate over number of features to select
# feature_counts = range(10, 71, 10)
# print(f"Starting evaluation with feature counts: {list(feature_counts)}")

# for k in feature_counts:
#     print(f"\nProcessing with {k} features...")
    
#     # For traditional feature selection methods
#     for fs_method in ['Chi-Square', 'ANOVA', 'Mutual Information']:
#         print(f"  Applying {fs_method} feature selection...")
#         fs = get_best_features_selector(fs_method, k)
        
#         X_train_fs = fs.fit_transform(X_train, y_train)
#         X_test_fs = fs.transform(X_test)

#         fs_results = {metric: [] for metric in ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'AUC-ROC']}
        
#         for model_name, model in models.items():
#             print(f"    Training {model_name}...")
#             model.fit(X_train_fs, y_train)
#             y_pred = model.predict(X_test_fs)
#             y_prob = model.predict_proba(X_test_fs)[:, 1]

#             fs_results['Accuracy'].append(accuracy_score(y_test, y_pred))
#             fs_results['Precision'].append(precision_score(y_test, y_pred))
#             fs_results['Recall'].append(recall_score(y_test, y_pred))
#             fs_results['F1 Score'].append(f1_score(y_test, y_pred))
#             fs_results['AUC-ROC'].append(roc_auc_score(y_test, y_prob))
#             print(f"    {model_name} evaluation complete")

#         for metric in fs_results:
#             results[metric][fs_method].append(np.mean(fs_results[metric]))
#         print(f"  {fs_method} feature selection complete")

#     # For GAN feature set
#     print(f"  Applying GAN feature selection...")
#     X_train_GAN = X_train[:, [X.columns.get_loc(f) for f in GAN_features[:k]]]
#     X_test_GAN = X_test[:, [X.columns.get_loc(f) for f in GAN_features[:k]]]

#     GAN_results = {metric: [] for metric in ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'AUC-ROC']}

#     for model_name, model in models.items():
#         print(f"    Training {model_name} with GAN features...")
#         model.fit(X_train_GAN, y_train)
#         y_pred = model.predict(X_test_GAN)
#         y_prob = model.predict_proba(X_test_GAN)[:, 1]

#         GAN_results['Accuracy'].append(accuracy_score(y_test, y_pred))
#         GAN_results['Precision'].append(precision_score(y_test, y_pred))
#         GAN_results['Recall'].append(recall_score(y_test, y_pred))
#         GAN_results['F1 Score'].append(f1_score(y_test, y_pred))
#         GAN_results['AUC-ROC'].append(roc_auc_score(y_test, y_prob))
#         print(f"    {model_name} evaluation complete")

#     for metric in GAN_results:
#         results[metric]['GAN_FS'].append(np.mean(GAN_results[metric]))
#     print(f"  GAN feature selection complete")

#     print(f"Completed evaluation with {k} features")

# print("All feature selection evaluations complete. Generating plots...")

# # Plotting the results
# plt.figure(figsize=(15, 10))
# metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'AUC-ROC']
# for idx, metric in enumerate(metrics, 1):
#     plt.subplot(2, 3, idx)
#     for method in ['Chi-Square', 'ANOVA', 'Mutual Information', 'GAN_FS']:
#         plt.plot(feature_counts, results[metric][method], label=method)
#     plt.title(metric)
#     plt.xlabel('Number of Features')
#     plt.ylabel(metric)
#     plt.legend()
#     plt.xticks(feature_counts)

# plt.tight_layout()
# print("Displaying performance comparison plots...")
# plt.show()

# print("Experiment completed successfully!")
# Out:
# Starting DDoS detection feature selection experiment...
# Loading dataset...
# Dataset loaded: 103154 samples with 81 features
# Splitting data into training and test sets...
# Training set: 72207 samples, Test set: 30947 samples
# Standardizing features...
# Feature standardization complete
# Defining top features based on sensitivity ranking and synergistic pairs...
# Creating combined feature set...
# Combined feature set created with 71 features
# Initializing machine learning models...
# Initialized 3 models: Logistic Regression, Random Forest, Support Vector Machine
# Starting evaluation with feature counts: [10, 20, 30, 40, 50, 60, 70]
#
# Processing with 10 features...
#   Applying Chi-Square feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Chi-Square feature selection complete
#   Applying ANOVA feature selection...
#     Training Logistic Regression...
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:114: UserWarning: Features [33 34 35 45 48 52 58 59 60 61 62 63] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   ANOVA feature selection complete
#   Applying Mutual Information feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Mutual Information feature selection complete
#   Applying Combined feature selection...
#     Training Logistic Regression with combined features...
#     Logistic Regression evaluation complete
#     Training Random Forest with combined features...
#     Random Forest evaluation complete
#     Training Support Vector Machine with combined features...
#     Support Vector Machine evaluation complete
#   Combined feature selection complete
# Completed evaluation with 10 features
#
# Processing with 20 features...
#   Applying Chi-Square feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Chi-Square feature selection complete
#   Applying ANOVA feature selection...
#     Training Logistic Regression...
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:114: UserWarning: Features [33 34 35 45 48 52 58 59 60 61 62 63] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   ANOVA feature selection complete
#   Applying Mutual Information feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Mutual Information feature selection complete
#   Applying Combined feature selection...
#     Training Logistic Regression with combined features...
#     Logistic Regression evaluation complete
#     Training Random Forest with combined features...
#     Random Forest evaluation complete
#     Training Support Vector Machine with combined features...
#     Support Vector Machine evaluation complete
#   Combined feature selection complete
# Completed evaluation with 20 features
#
# Processing with 30 features...
#   Applying Chi-Square feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Chi-Square feature selection complete
#   Applying ANOVA feature selection...
#     Training Logistic Regression...
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:114: UserWarning: Features [33 34 35 45 48 52 58 59 60 61 62 63] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   ANOVA feature selection complete
#   Applying Mutual Information feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Mutual Information feature selection complete
#   Applying Combined feature selection...
#     Training Logistic Regression with combined features...
#     Logistic Regression evaluation complete
#     Training Random Forest with combined features...
#     Random Forest evaluation complete
#     Training Support Vector Machine with combined features...
#     Support Vector Machine evaluation complete
#   Combined feature selection complete
# Completed evaluation with 30 features
#
# Processing with 40 features...
#   Applying Chi-Square feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Chi-Square feature selection complete
#   Applying ANOVA feature selection...
#     Training Logistic Regression...
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:114: UserWarning: Features [33 34 35 45 48 52 58 59 60 61 62 63] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   ANOVA feature selection complete
#   Applying Mutual Information feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Mutual Information feature selection complete
#   Applying Combined feature selection...
#     Training Logistic Regression with combined features...
#     Logistic Regression evaluation complete
#     Training Random Forest with combined features...
#     Random Forest evaluation complete
#     Training Support Vector Machine with combined features...
#     Support Vector Machine evaluation complete
#   Combined feature selection complete
# Completed evaluation with 40 features
#
# Processing with 50 features...
#   Applying Chi-Square feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Chi-Square feature selection complete
#   Applying ANOVA feature selection...
#     Training Logistic Regression...
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:114: UserWarning: Features [33 34 35 45 48 52 58 59 60 61 62 63] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   ANOVA feature selection complete
#   Applying Mutual Information feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Mutual Information feature selection complete
#   Applying Combined feature selection...
#     Training Logistic Regression with combined features...
#     Logistic Regression evaluation complete
#     Training Random Forest with combined features...
#     Random Forest evaluation complete
#     Training Support Vector Machine with combined features...
#     Support Vector Machine evaluation complete
#   Combined feature selection complete
# Completed evaluation with 50 features
#
# Processing with 60 features...
#   Applying Chi-Square feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Chi-Square feature selection complete
#   Applying ANOVA feature selection...
#     Training Logistic Regression...
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:114: UserWarning: Features [33 34 35 45 48 52 58 59 60 61 62 63] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   ANOVA feature selection complete
#   Applying Mutual Information feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Mutual Information feature selection complete
#   Applying Combined feature selection...
#     Training Logistic Regression with combined features...
#     Logistic Regression evaluation complete
#     Training Random Forest with combined features...
#     Random Forest evaluation complete
#     Training Support Vector Machine with combined features...
#     Support Vector Machine evaluation complete
#   Combined feature selection complete
# Completed evaluation with 60 features
#
# Processing with 70 features...
#   Applying Chi-Square feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Chi-Square feature selection complete
#   Applying ANOVA feature selection...
#     Training Logistic Regression...
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:114: UserWarning: Features [33 34 35 45 48 52 58 59 60 61 62 63] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# /usr/lib/python3/dist-packages/sklearn/feature_selection/_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   ANOVA feature selection complete
#   Applying Mutual Information feature selection...
#     Training Logistic Regression...
#     Logistic Regression evaluation complete
#     Training Random Forest...
#     Random Forest evaluation complete
#     Training Support Vector Machine...
#     Support Vector Machine evaluation complete
#   Mutual Information feature selection complete
#   Applying Combined feature selection...
#     Training Logistic Regression with combined features...
#     Logistic Regression evaluation complete
#     Training Random Forest with combined features...
#     Random Forest evaluation complete
#     Training Support Vector Machine with combined features...
#     Support Vector Machine evaluation complete
#   Combined feature selection complete
# Completed evaluation with 70 features
# All feature selection evaluations complete. Generating plots...
# Displaying performance comparison plots...
# Experiment completed successfully!

# %%
print(results)
# Out:
# {'Accuracy': {'Chi-Square': [0.9992352516668283, 0.9992891071832487, 0.9992352516668283, 0.9992029383569759, 0.99921370946026, 0.9991921672536918, 0.9991921672536918], 'ANOVA': [0.9989982873945777, 0.9992244805635441, 0.9992460227701123, 0.9991921672536918, 0.9991921672536918, 0.9991813961504077, 0.9991598539438394], 'Mutual Information': [0.9966178735687897, 0.9983735634040994, 0.9982873945778267, 0.9991383117372713, 0.9991706250471236, 0.9991706250471236, 0.9991706250471236], 'Combined': [0.98996133173921, 0.999105998427419, 0.9990844562208507, 0.9991706250471236, 0.9991383117372713, 0.9991921672536918, 0.9991706250471236]}, 'Precision': {'Chi-Square': [0.999523709449313, 0.9994817515089052, 0.9995656715073126, 0.9995656697401932, 0.9995936721067532, 0.9995796517831215, 0.99959365679365], 'ANOVA': [0.9995655466250802, 0.9995656779848687, 0.999579679463238, 0.999565657372982, 0.999565657372982, 0.9995796441262481, 0.9995656308697073], 'Mutual Information': [0.9985823695949314, 0.9992709463914226, 0.999172847729394, 0.9995796023030362, 0.9995516358692903, 0.9995796541380922, 0.9995656420598787], 'Combined': [0.9879702792981876, 0.9995655607595101, 0.999565556640788, 0.9995656232124378, 0.9995656214451699, 0.99959365679365, 0.9995796429479703]}, 'Recall': {'Chi-Square': [0.9994816620436525, 0.9995937351152951, 0.9994396346417864, 0.9993976072399205, 0.9993835981059651, 0.9993695889720097, 0.9993555798380545], 'ANOVA': [0.9991314336947689, 0.9994256255078312, 0.9994396346417865, 0.9993835981059651, 0.9993835981059651, 0.9993555798380545, 0.999341570704099], 'Mutual Information': [0.9970160544675127, 0.9986130957384214, 0.9985990866044662, 0.999299543302233, 0.9993695889720097, 0.999341570704099, 0.9993555798380545], 'Combined': [0.9993555798380545, 0.9992715250343224, 0.9992435067664117, 0.9993555798380543, 0.9993135524361884, 0.9993555798380545, 0.999341570704099]}, 'F1 Score': {'Chi-Square': [0.9995026770656534, 0.9995377336058704, 0.9995026488069225, 0.9994816293644391, 0.9994886220070217, 0.9994746084569451, 0.999474602862429], 'ANOVA': [0.9993484411506826, 0.999495645270155, 0.9995096514600933, 0.999474617878611, 0.999474617878611, 0.9994675987373394, 0.9994535875423947], 'Mutual Information': [0.9977984575107611, 0.9989418935140048, 0.9988858678907132, 0.9994395527909029, 0.9994606028557248, 0.9994605954947079, 0.9994605987340183], 'Combined': [0.9935708781308371, 0.9994185133212836, 0.9994045027167152, 0.9994605901954478, 0.999439569869442, 0.999474602862429, 0.9994605913730076]}, 'AUC-ROC': {'Chi-Square': [0.9998057209464418, 0.9998293884117407, 0.9998410179710063, 0.9998425162217369, 0.9998388577480576, 0.9998390682865589, 0.9998467358050037], 'ANOVA': [0.9997108963639287, 0.9998467514729851, 0.9998415624333634, 0.9998425955408933, 0.9998410052407714, 0.999848416196019, 0.9998466829255661], 'Mutual Information': [0.9983143611899744, 0.9996670553932047, 0.9997262176913345, 0.9998446402124784, 0.9998431145427803, 0.9998568798437737, 0.9998567574376681], 'Combined': [0.9975012350580189, 0.9998206045496144, 0.9996514216854179, 0.9998269001404294, 0.9998290114009359, 0.9998540380636297, 0.9998469296962748]}}
